# %% [markdown]
# # ⚠️ Уведомление о миграции
#
# Этот notebook был автоматически обновлен для работы с новой модульной архитектурой SAMe:
#
# - 🧹 **same_clear** - Обработка и очистка текста
# - 🔍 **same_search** - Поиск и индексация
# - 🌐 **same_api** - API и интеграции
#
# 📚 См. [MIGRATION_GUIDE.md](../../MIGRATION_GUIDE.md) для подробной информации.
#
# ---

# %% [markdown]
# # Проект SAMe: Комплексный анализ системы поиска аналогов
#
# ## 📊 Анализ основного датасета для оптимизации поиска аналогов
#
# Данный notebook предоставляет комплексную аналитическую платформу для системы поиска аналогов проекта SAMe (Search Analog Model Engine). Анализ сосредоточен на каталоге `main_dataset.xlsx` для оптимизации производительности поиска, сопоставления по сходству и категоризации.
#
# ### 🎯 Цели анализа:
# 1. **Обзор данных и оценка качества** - Структура датасета и метрики качества
# 2. **Текстовый анализ для оптимизации поиска** - Предобработка названий/описаний товаров
# 3. **Метрики сходства и сопоставления** - Сравнение алгоритмов и оптимизация
# 4. **Анализ категоризации и кластеризации** - Группировка и классификация товаров
# 5. **Оптимизация производительности поиска** - Структура индексов и рекомендации по производительности
# 6. **Визуализация и выводы** - Интерактивные визуализации и результаты
#
# ---

# %% [markdown]
# ## 🔧 Настройка и импорты

# %%
# Основные библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Обработка текста
import re
from collections import Counter, defaultdict
import string

# NLP библиотеки
try:
    import spacy
    nlp = spacy.load('ru_core_news_sm')
    SPACY_AVAILABLE = True
except:
    SPACY_AVAILABLE = False
    print("⚠️ Русская модель SpaCy недоступна. Некоторые NLP функции будут ограничены.")

# Библиотеки для сходства и машинного обучения
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# Нечеткое сопоставление
from rapidfuzz import fuzz, process
from fuzzywuzzy import fuzz as fuzz_wuzzy

# Визуализация
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)

# Импорты проекта SAMe
import sys
sys.path.append('../../src')

try:
    from same.data_manager import data_helper
    from same_clear.text_processing.text_cleaner import TextCleaner, CleaningConfig
    from same_clear.text_processing.lemmatizer import Lemmatizer, LemmatizerConfig
    from same_clear.text_processing.normalizer import TextNormalizer, NormalizerConfig
    SAME_MODULES_AVAILABLE = True
    print("✅ Модули SAMe успешно загружены")
except ImportError as e:
    SAME_MODULES_AVAILABLE = False
    print(f"⚠️ Модули SAMe недоступны: {e}")

# Конфигурация
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("🚀 Настройка завершена успешно!")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# ✅ Модули SAMe успешно загружены
# 🚀 Настройка завершена успешно!

# %% [markdown]
# ## 📂 Загрузка данных и первичное исследование

# %%
# Загрузка основного датасета
dataset_path = Path('../../src/data/input/main_dataset.xlsx')

if not dataset_path.exists():
    raise FileNotFoundError(f"Датасет не найден по пути {dataset_path}")

print(f"📂 Загрузка датасета из: {dataset_path}")
df = pd.read_excel(dataset_path)

print(f"✅ Датасет загружен успешно!")
print(f"📊 Размер: {df.shape[0]:,} строк × {df.shape[1]} столбцов")
print(f"💾 Использование памяти: {df.memory_usage(deep=True).sum() / 1024**2:.2f} МБ")
# Out:
# 📂 Загрузка датасета из: ../../src/data/input/main_dataset.xlsx
# ✅ Датасет загружен успешно!
# 📊 Размер: 130,303 строк × 6 столбцов
# 💾 Использование памяти: 89.13 МБ

# %% [markdown]
# ## 1️⃣ Обзор данных и оценка качества

# %% [markdown]
# ### 1.1 Анализ структуры датасета

# %%
# Основная информация о датасете
print("=== СТРУКТУРА ДАТАСЕТА ===")
print(f"Столбцы ({len(df.columns)}): {list(df.columns)}")
print(f"\nТипы данных:")
print(df.dtypes)

# Отображение первых строк
print(f"\n=== ОБРАЗЕЦ ДАННЫХ ===")
display(df.head())
# Out:
# === СТРУКТУРА ДАТАСЕТА ===
# Столбцы (6): ['Код', 'Наименование', 'НаименованиеПолное', 'Группа', 'ВидНоменклатуры', 'ЕдиницаИзмерения']
#
# Типы данных:
# Код                   object
# Наименование          object
# НаименованиеПолное    object
# Группа                object
# ВидНоменклатуры       object
# ЕдиницаИзмерения      object
# dtype: object
#
# === ОБРАЗЕЦ ДАННЫХ ===
#             Код                                       Наименование  \
# 0  НИ-IS0032430  Cветильник LED панель 50W 6500k IP40 1200мм ДП...
# 1  НИ-IS0040225  Cветильник потолочный,Osairous,Белый, 30Вт LED...
# 2  НИ-IS0014483  Cистема IP-DECT Yealink W80DM контроллер микро...
# 3  НИ-IS0047648     Cпрей для ванной комнаты Sanfor (Санфор) 500мл
# 4  НИ-IS0047649            Cпрей ультрабелый Sanfor (Санфор) 500мл
#
#                                   НаименованиеПолное           Группа  \
# 0  Cветильник LED панель 50W 6500k IP40 1200мм ДП...  АВАНСОВЫЙ ОТЧЕТ
# 1  Cветильник потолочный,Osairous,Белый, 30Вт LED...  АВАНСОВЫЙ ОТЧЕТ
# 2  Cистема IP-DECT Yealink W80DM контроллер микро...  АВАНСОВЫЙ ОТЧЕТ
# 3     Cпрей для ванной комнаты Sanfor (Санфор) 500мл  АВАНСОВЫЙ ОТЧЕТ
# 4            Cпрей ультрабелый Sanfor (Санфор) 500мл  АВАНСОВЫЙ ОТЧЕТ
#
#                             ВидНоменклатуры ЕдиницаИзмерения
# 0  Инвентарь и хозяйственные принадлежности               шт
# 1                         Сырье и материалы               шт
# 2  Инвентарь и хозяйственные принадлежности               шт
# 3                         Сырье и материалы               шт
# 4                         Сырье и материалы               шт

# %%
# Определение ключевых столбцов для поиска аналогов
key_columns = {
    'product_name': ['Наименование', 'Наименование МТР', 'Name', 'Product_Name'],
    'category': ['Группа', 'Group', 'Category'],
    'subcategory': ['ВидНоменклатуры', 'Product_Type', 'Subcategory'],
    'description': ['Описание', 'Description', 'Desc'],
    'unit': ['ЕдиницаИзмерения', 'Unit', 'Measure']
}

found_columns = {}
for key, possible_names in key_columns.items():
    for name in possible_names:
        if name in df.columns:
            found_columns[key] = name
            break
    if key not in found_columns:
        found_columns[key] = None

print("=== СОПОСТАВЛЕНИЕ КЛЮЧЕВЫХ СТОЛБЦОВ ===")
for key, column in found_columns.items():
    status = "✅" if column else "❌"
    key_ru = {
        'product_name': 'название_товара',
        'category': 'категория', 
        'subcategory': 'подкategория',
        'description': 'описание',
        'unit': 'единица_измерения'
    }
    print(f"{status} {key_ru.get(key, key)}: {column}")

# Сохранение основных столбцов для анализа
MAIN_NAME_COL = found_columns['product_name']
CATEGORY_COL = found_columns['category']
SUBCATEGORY_COL = found_columns['subcategory']

# Проверка доступности данных для анализа
if MAIN_NAME_COL:
    print(f"\n🔍 ПРОВЕРКА ДАННЫХ:")
    print(f"Основной столбец: {MAIN_NAME_COL}")
    if MAIN_NAME_COL in df.columns:
        sample_data = df[MAIN_NAME_COL].dropna().head(3)
        print(f"Примеры данных:")
        for i, item in enumerate(sample_data, 1):
            print(f"  {i}. {item}")
    else:
        print(f"❌ Столбец {MAIN_NAME_COL} не найден!")
else:
    print(f"\n❌ Основной столбец с названиями товаров не определен")
# Out:
# === СОПОСТАВЛЕНИЕ КЛЮЧЕВЫХ СТОЛБЦОВ ===
# ✅ название_товара: Наименование
# ✅ категория: Группа
# ✅ подкategория: ВидНоменклатуры
# ❌ описание: None
# ✅ единица_измерения: ЕдиницаИзмерения
#
# 🔍 ПРОВЕРКА ДАННЫХ:
# Основной столбец: Наименование
# Примеры данных:
#   1. Cветильник LED панель 50W 6500k IP40 1200мм ДПО-108 Призма Neox
#   2. Cветильник потолочный,Osairous,Белый, 30Вт LED, 6500K Светодиодная потолочная
#   3. Cистема IP-DECT Yealink W80DM контроллер микросота DECT

# %% [markdown]
# ### 1.2 Метрики качества данных

# %%
# Анализ пропущенных значений
missing_data = df.isnull().sum()
missing_percent = (missing_data / len(df)) * 100

quality_df = pd.DataFrame({
    'Количество_пропусков': missing_data,
    'Процент_пропусков': missing_percent,
    'Тип_данных': df.dtypes
})
quality_df = quality_df[quality_df['Количество_пропусков'] > 0].sort_values('Процент_пропусков', ascending=False)

print("=== АНАЛИЗ ПРОПУЩЕННЫХ ДАННЫХ ===")
if len(quality_df) > 0:
    display(quality_df)
else:
    print("✅ Пропущенные данные не найдены!")

# Анализ дубликатов
if MAIN_NAME_COL:
    # Убедимся, что столбец существует и содержит данные
    if MAIN_NAME_COL in df.columns:
        # Очистим данные от NaN и пустых строк
        clean_names = df[MAIN_NAME_COL].dropna().astype(str)
        clean_names = clean_names[clean_names.str.strip() != '']
        
        total_products = len(clean_names)
        unique_names = clean_names.nunique()
        duplicates = total_products - unique_names
        duplicate_rate = (duplicates / total_products) * 100 if total_products > 0 else 0
        
        print(f"\n=== АНАЛИЗ ДУБЛИКАТОВ ===")
        print(f"Всего товаров (после очистки): {total_products:,}")
        print(f"Уникальных названий: {unique_names:,}")
        print(f"Дубликатов: {duplicates:,} ({duplicate_rate:.2f}%)")
        
        if duplicates > 0 and total_products > 0:
            # Показать наиболее частые дубликаты
            duplicate_names = clean_names.value_counts().head(15)
            duplicate_names = duplicate_names[duplicate_names > 1]
            
            if len(duplicate_names) > 0:
                print(f"\nТоп дублирующихся названий товаров:")
                for name, count in duplicate_names.items():
                    print(f"  • {name}: {count} вхождений")
            else:
                print(f"\n✅ Точных дубликатов не найдено!")
        else:
            print(f"\n✅ Дубликаты не обнаружены!")
    else:
        print(f"\n❌ Столбец {MAIN_NAME_COL} не найден в датасете")
else:
    print(f"\n❌ Основной столбец с названиями товаров не определен")
# Out:
# === АНАЛИЗ ПРОПУЩЕННЫХ ДАННЫХ ===
#                     Количество_пропусков  Процент_пропусков Тип_данных
# НаименованиеПолное                   108           0.082884     object
# ЕдиницаИзмерения                      25           0.019186     object
# === АНАЛИЗ ДУБЛИКАТОВ ===
# Всего товаров (после очистки): 130,303
# Уникальных названий: 128,937
# Дубликатов: 1,366 (1.05%)
#
# Топ дублирующихся названий товаров:
#   • Выключатель автоматический модульный ВА47-100-3С80-УХЛ3-КЭАЗ 141629: 22 вхождений
#   • Емкость пластиковая под питьевую воду 50 л: 20 вхождений
#   • Вентилятор вытяжной Blauberg Aero Vintage 125: 19 вхождений
#   • Ключ шарнирный КШС 219-245: 8 вхождений
#   • Ключ трубный цепной облегченный КЦО-1: 8 вхождений
#   • Насос электрический погружной PETROLL Spire 24V (52мм): 7 вхождений
#   • Штроп эксплуатационный ШЭ-32: 6 вхождений
#   • Ключ шарнирный КШС 73-89 ТУ 342216-75: 6 вхождений
#   • Сапоги кожаные с жестким подноском: 6 вхождений
#   • Ключ шарнирный КШС-108-127: 6 вхождений
#   • БелАК Насос перекачки топлива помповый 24V "Стандарт" комплект: фильтр грубой очистки, 3 хомута, болты крепления БАК.11024: 6 вхождений
#   • Агрегат насосный консольный К65-50-160 с электродвигателем 5,5 кВт: 5 вхождений
#   • Пистолет для монтажной пены: 5 вхождений
#   • Точка контрольная ТП-00000629: 5 вхождений
#   • Услуги Инженерное сопровождение: 5 вхождений

# %% [markdown]
# ### 1.3 Визуализация качества данных

# %%
# Создание визуализаций для оценки качества
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=('Пропущенные данные по столбцам', 'Распределение типов данных', 
                   'Анализ дубликатов', 'Полнота столбцов'),
    specs=[[{"type": "bar"}, {"type": "pie"}],
           [{"type": "bar"}, {"type": "bar"}]]
)

# График пропущенных данных
if len(quality_df) > 0:
    fig.add_trace(
        go.Bar(x=quality_df.index, y=quality_df['Процент_пропусков'],
               name='Пропуски %', marker_color='red'),
        row=1, col=1
    )

# Распределение типов данных
dtype_counts = df.dtypes.value_counts()
fig.add_trace(
    go.Pie(labels=dtype_counts.index.astype(str), values=dtype_counts.values,
           name="Типы данных"),
    row=1, col=2
)

# График дубликатов
if MAIN_NAME_COL and MAIN_NAME_COL in df.columns:
    # Подготовка данных для анализа дубликатов
    clean_names_for_viz = df[MAIN_NAME_COL].dropna().astype(str)
    clean_names_for_viz = clean_names_for_viz[clean_names_for_viz.str.strip() != '']
    
    if len(clean_names_for_viz) > 0:
        duplicate_counts = clean_names_for_viz.value_counts()
        duplicate_stats = {
            'Уникальные': sum(duplicate_counts == 1),
            'Дубликаты (2-5)': sum((duplicate_counts >= 2) & (duplicate_counts <= 5)),
            'Дубликаты (6-10)': sum((duplicate_counts >= 6) & (duplicate_counts <= 10)),
            'Дубликаты (>10)': sum(duplicate_counts > 10)
        }
        
        fig.add_trace(
            go.Bar(x=list(duplicate_stats.keys()), y=list(duplicate_stats.values()),
                   name='Дубликаты', marker_color='orange'),
            row=2, col=1
        )

# Полнота столбцов
completeness = ((len(df) - missing_data) / len(df)) * 100
fig.add_trace(
    go.Bar(x=df.columns, y=completeness,
           name='Полнота %', marker_color='green'),
    row=2, col=2
)

fig.update_layout(height=800, showlegend=False, title_text="Панель оценки качества данных")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="c3cd2ff9-1ae4-49fb-984b-3a41433688df" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c3cd2ff9-1ae4-49fb-984b-3a41433688df")) {                    Plotly.newPlot(                        "c3cd2ff9-1ae4-49fb-984b-3a41433688df",                        [{"marker":{"color":"red"},"name":"\u041f\u0440\u043e\u043f\u0443\u0441\u043a\u0438 %","x":["\u041d\u0430\u0438\u043c\u0435\u043d\u043e\u0432\u0430\u043d\u0438\u0435\u041f\u043e\u043b\u043d\u043e\u0435","\u0415\u0434\u0438\u043d\u0438\u0446\u0430\u0418\u0437\u043c\u0435\u0440\u0435\u043d\u0438\u044f"],"y":{"dtype":"f8","bdata":"FImNad43tT+93eEVgqWTPw=="},"type":"bar","xaxis":"x","yaxis":"y"},{"labels":["object"],"name":"\u0422\u0438\u043f\u044b \u0434\u0430\u043d\u043d\u044b\u0445","values":{"dtype":"i1","bdata":"Bg=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.625,1.0]}},{"marker":{"color":"orange"},"name":"\u0414\u0443\u0431\u043b\u0438\u043a\u0430\u0442\u044b","x":["\u0423\u043d\u0438\u043a\u0430\u043b\u044c\u043d\u044b\u0435","\u0414\u0443\u0431\u043b\u0438\u043a\u0430\u0442\u044b (2-5)","\u0414\u0443\u0431\u043b\u0438\u043a\u0430\u0442\u044b (6-10)","\u0414\u0443\u0431\u043b\u0438\u043a\u0430\u0442\u044b (\u003e10)"],"y":[127765,1161,8,3],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"green"},"name":"\u041f\u043e\u043b\u043d\u043e\u0442\u0430 %","x":["\u041a\u043e\u0434","\u041d\u0430\u0438\u043c\u0435\u043d\u043e\u0432\u0430\u043d\u0438\u0435","\u041d\u0430\u0438\u043c\u0435\u043d\u043e\u0432\u0430\u043d\u0438\u0435\u041f\u043e\u043b\u043d\u043e\u0435","\u0413\u0440\u0443\u043f\u043f\u0430","\u0412\u0438\u0434\u041d\u043e\u043c\u0435\u043d\u043a\u043b\u0430\u0442\u0443\u0440\u044b","\u0415\u0434\u0438\u043d\u0438\u0446\u0430\u0418\u0437\u043c\u0435\u0440\u0435\u043d\u0438\u044f"],"y":{"dtype":"f8","bdata":"AAAAAAAAWUAAAAAAAABZQJ6cZQiy+lhAAAAAAAAAWUAAAAAAAABZQOKh3qfF\u002flhA"},"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"s ...

# %% [markdown]
# ## 2️⃣ Текстовый анализ для оптимизации поиска

# %% [markdown]
# ### 2.1 Анализ предобработки текста названий товаров

# %%
if not MAIN_NAME_COL:
    print("❌ Основной столбец с названиями товаров не найден. Пропускаем текстовый анализ.")
else:
    # Извлечение названий товаров для анализа
    product_names = df[MAIN_NAME_COL].dropna().astype(str)
    
    print(f"=== ОБЗОР ТЕКСТОВОГО АНАЛИЗА ===")
    print(f"Всего названий товаров: {len(product_names):,}")
    print(f"Уникальных названий товаров: {product_names.nunique():,}")
    print(f"Средняя длина названия: {product_names.str.len().mean():.1f} символов")
    print(f"Медианная длина названия: {product_names.str.len().median():.1f} символов")
    
    # Статистика символов и слов
    name_lengths = product_names.str.len()
    word_counts = product_names.str.split().str.len()
    
    print(f"\n=== СТАТИСТИКА ДЛИНЫ ===")
    print(f"Минимальная длина: {name_lengths.min()} символов")
    print(f"Максимальная длина: {name_lengths.max()} символов")
    print(f"Стандартное отклонение: {name_lengths.std():.1f} символов")
    print(f"\nСреднее количество слов в названии: {word_counts.mean():.1f}")
    print(f"Максимальное количество слов в названии: {word_counts.max()}")
# Out:
# === ОБЗОР ТЕКСТОВОГО АНАЛИЗА ===
# Всего названий товаров: 130,303
# Уникальных названий товаров: 128,937
# Средняя длина названия: 49.0 символов
# Медианная длина названия: 44.0 символов
#
# === СТАТИСТИКА ДЛИНЫ ===
# Минимальная длина: 3 символов
# Максимальная длина: 150 символов
# Стандартное отклонение: 24.1 символов
#
# Среднее количество слов в названии: 6.3
# Максимальное количество слов в названии: 31

# %%
# Анализ текстовых паттернов
if MAIN_NAME_COL:
    # Паттерны определения языка
    cyrillic_pattern = re.compile(r'[а-яё]', re.IGNORECASE)
    latin_pattern = re.compile(r'[a-z]', re.IGNORECASE)
    numeric_pattern = re.compile(r'\d')
    special_chars_pattern = re.compile(r'[^\w\s]')
    
    cyrillic_count = product_names.str.contains(cyrillic_pattern).sum()
    latin_count = product_names.str.contains(latin_pattern).sum()
    numeric_count = product_names.str.contains(numeric_pattern).sum()
    special_chars_count = product_names.str.contains(special_chars_pattern).sum()
    
    print(f"=== АНАЛИЗ ТЕКСТОВЫХ ПАТТЕРНОВ ===")
    print(f"Названия с кириллицей: {cyrillic_count:,} ({cyrillic_count/len(product_names)*100:.1f}%)")
    print(f"Названия с латиницей: {latin_count:,} ({latin_count/len(product_names)*100:.1f}%)")
    print(f"Названия с цифрами: {numeric_count:,} ({numeric_count/len(product_names)*100:.1f}%)")
    print(f"Названия со спецсимволами: {special_chars_count:,} ({special_chars_count/len(product_names)*100:.1f}%)")
    
    # Общие паттерны
    print(f"\n=== ОБЩИЕ ПАТТЕРНЫ ===")
    
    # Паттерны размеров/измерений
    size_patterns = [
        (r'\d+[xх]\d+', 'Размеры (NxN)'),
        (r'\d+\s*мм', 'Миллиметры'),
        (r'\d+\s*см', 'Сантиметры'),
        (r'\d+\s*м(?!м)', 'Метры'),
        (r'М\d+', 'М-размер (М10, М12, и т.д.)'),
        (r'\d+\s*кг', 'Вес в кг'),
        (r'\d+\s*л', 'Объем в литрах')
    ]
    
    for pattern, description in size_patterns:
        count = product_names.str.contains(pattern, case=False, regex=True).sum()
        if count > 0:
            print(f"  • {description}: {count:,} названий ({count/len(product_names)*100:.1f}%)")
# Out:
# === АНАЛИЗ ТЕКСТОВЫХ ПАТТЕРНОВ ===
# Названия с кириллицей: 130,296 (100.0%)
# Названия с латиницей: 62,975 (48.3%)
# Названия с цифрами: 123,353 (94.7%)
# Названия со спецсимволами: 103,738 (79.6%)
#
# === ОБЩИЕ ПАТТЕРНЫ ===
#   • Размеры (NxN): 16,895 названий (13.0%)
#   • Миллиметры: 17,021 названий (13.1%)
#   • Сантиметры: 1,489 названий (1.1%)
#   • Метры: 11,078 названий (8.5%)
#   • М-размер (М10, М12, и т.д.): 4,805 названий (3.7%)
#   • Вес в кг: 1,732 названий (1.3%)
#   • Объем в литрах: 3,968 названий (3.0%)

# %% [markdown]
# ### 2.2 Распределение длины и сложности текста

# %%
if MAIN_NAME_COL:
    # Создание визуализаций для текстового анализа
    fig = make_subplots(
        rows=2, cols=2,
        subplot_titles=('Распределение длины символов', 'Распределение количества слов',
                       'Распределение языковых паттернов', 'Топ-20 наиболее частых слов'),
        specs=[[{"type": "histogram"}, {"type": "histogram"}],
               [{"type": "pie"}, {"type": "bar"}]]
    )
    
    # Распределение длины символов
    fig.add_trace(
        go.Histogram(x=name_lengths, nbinsx=50, name='Длина символов',
                    marker_color='blue', opacity=0.7),
        row=1, col=1
    )
    
    # Распределение количества слов
    fig.add_trace(
        go.Histogram(x=word_counts, nbinsx=20, name='Количество слов',
                    marker_color='green', opacity=0.7),
        row=1, col=2
    )
    
    # Круговая диаграмма языковых паттернов
    mixed_count = sum(product_names.str.contains(cyrillic_pattern) & 
                     product_names.str.contains(latin_pattern))
    pattern_data = {
        'Только кириллица': cyrillic_count - mixed_count,
        'Только латиница': latin_count - mixed_count,
        'Смешанный': mixed_count,
        'Другое': len(product_names) - cyrillic_count - latin_count + mixed_count
    }
    
    fig.add_trace(
        go.Pie(labels=list(pattern_data.keys()), values=list(pattern_data.values()),
               name="Языковые паттерны"),
        row=2, col=1
    )
    
    # Наиболее частые слова
    all_words = ' '.join(product_names.str.lower()).split()
    # Удаление общих русских стоп-слов и коротких слов
    stop_words = {'и', 'в', 'на', 'с', 'по', 'для', 'из', 'от', 'до', 'при', 'без', 'под', 'над'}
    filtered_words = [word for word in all_words if len(word) > 2 and word not in stop_words]
    word_freq = Counter(filtered_words).most_common(20)
    
    words, counts = zip(*word_freq) if word_freq else ([], [])
    fig.add_trace(
        go.Bar(x=list(words), y=list(counts), name='Частота слов',
               marker_color='orange'),
        row=2, col=2
    )
    
    fig.update_layout(height=800, showlegend=False, 
                     title_text="Панель текстового анализа")
    fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b97263a0-7e96-4055-b28b-6bede35ce46e" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b97263a0-7e96-4055-b28b-6bede35ce46e")) {                    Plotly.newPlot(                        "b97263a0-7e96-4055-b28b-6bede35ce46e",                        [{"marker":{"color":"blue"},"name":"\u0414\u043b\u0438\u043d\u0430 \u0441\u0438\u043c\u0432\u043e\u043b\u043e\u0432","nbinsx":50,"opacity":0.7,"x":{"dtype":"i2","bdata":"...\...\...\...\u002fACsANgApACQALQAkACUALwAnAEkAKgAZADgAOgA3ACoAKgApADMAOAAmADMAQwBOACoAEwAXABUAFwAhAB0AEwAqAC0ALwBxADsAbgAeAEQARwAmADQAKAAzACEALQA\u002fAEAAKgA0ABAAEAA0AFkAMQA0AEoAOQA1ADYANgA2ADQANABOAEIAKABVADwASwBiAF0ASwBpAGYAZgBLAC8AMAAyAD4ALQAvADYAWwA0AEEAQQBXAFwAHwAaACMARQBxAEUAPQBFADQATAA+AFQAVAA+AEcAaABRAGAASABVAEsAUABBACQAOQA5AFMAXABDAFMAZQBfAD0AKQA\...\\u002fACcAOAAeAB4ANQA5ABsAWwA3ABsAQwAqAAoAPAA6AC0AHgAlADoAOwBTAB8ANgBHADcAKwA\\...\...\...\...\...\u002fAD8AWwBaAFkATgAnAEgAMgCRAEgALQBlAEMAQwAnACsALQAvACgASQAhADQAPgA\...\...\u002fACcAHgAyACwAQgAWAB4AHAAcABwAHAAeADMAHQAgACAAMAAsAFMARQA+AD0ARQA9ADsAOQBPAC0AGgAiADsAHwBKACcANQBWACQARAAjABwAQQBDAC8AMAAiACgAKAARABQAHAAiAB8AIAAgACAAIgAnABsAOgBNADEAGAAYABIAGgAgACAAIwAjACMALAAaADYAHQBXAFcAMgBFADUAIgA\...\...\\...\...\u002fADsARQApAB0AMQBDADkAJQAxAEQATgA1AEUAEAB9AEAAHQAdAHEAKgAsADsASQAfAFkAagA6AC8AIAAfAC8AKwAhAEIAJgAxAC0AiABEACoAJwAxAB0APAAoACsAIABgADkAOwAkACoAbgA\...\...\...\\u002fAEUAPQBIAEgAPgAoADkAOgA6AB0AJABMAEAAHQAdAGQAMAAwABoAGwAaABkAGgAbABoAKAAoADkAGgAiAEIAEAAQABAAOAAqACgAKgAoADsAMQAxADEAMQAxADEAKAA5ACgAKAAoAEgASgAtACUAJwAlACMAIAAnACkAJwA\\ ...

# %% [markdown]
# ### 2.3 Предобработка текста с модулями SAMe

# %%
# Тестирование модулей обработки текста SAMe, если доступны
if SAME_MODULES_AVAILABLE and MAIN_NAME_COL:
    print("=== ТЕСТИРОВАНИЕ ОБРАБОТКИ ТЕКСТА SAMe ===")
    
    # Выборка названий товаров для тестирования
    sample_names = product_names.sample(min(100, len(product_names))).tolist()
    
    try:
        # Инициализация процессоров текста
        cleaner = TextCleaner(CleaningConfig())
        normalizer = TextNormalizer(NormalizerConfig())
        
        if SPACY_AVAILABLE:
            lemmatizer = Lemmatizer(LemmatizerConfig())
        
        # Обработка образцов названий
        processed_results = []
        
        for name in sample_names[:500]:  # Обработка первых 10 для демонстрации
            result = {
                'оригинал': name,
                'очищенный': cleaner.clean_text(name),
                'нормализованный': normalizer.normalize_text(name)
            }
            
            if SPACY_AVAILABLE:
                result['лемматизированный'] = lemmatizer.lemmatize_text(name)
            
            processed_results.append(result)
        
        # Отображение результатов
        processing_df = pd.DataFrame(processed_results)
        print("\nРезультаты обработки текста:")
        display(processing_df)
        
    except Exception as e:
        print(f"⚠️ Ошибка в обработке текста SAMe: {e}")
        
else:
    print("⚠️ Модули SAMe недоступны или основной столбец названий не найден")
# Out:
# === ТЕСТИРОВАНИЕ ОБРАБОТКИ ТЕКСТА SAMe ===
#
# Результаты обработки текста:
#                                              оригинал  \
# 0   Фитинг гидравлический стальной резьба прямой #...
# 1       Кольцо уплотнительное 305-320-85 ГОСТ 9833-73
# 2                               Тумба бу(24374-13025)
# 3                       Замок вис. дисковый ВС2-26 СР
# 4                                Тяга 14006.55.151-01
# 5          Уплотнение цилиндровой втулки 54025.53.385
# 6                           Клапан челночный, HC01-07
# 7   Маркер белый для промышленной графики наконечн...
# 8   Шаблон полимерный под СБТ 114мм ТУ 3666-061-40...
# 9         Вагон-дом прачечная-душевая, на санях 20299
# 10  Футболка хлопковая цвет васильковый (112/182-188)
# 11  Сальник для ввода кабеля в щитовое оборудовани...
# 12  Кольцо 815-830-85-2-3  000.003.675.0 ГОСТ 1882...
# 13                                  Тройник ПЭ 110*50
# 14                       Карандаш разметочный, 145 мм
# 15  Картриджи для HP CF400x ,401x, 402x, 403x и Ca...
# 16  Подвеска хвостовика гидромеханическая цементир...
# 17             Захват клиньевой DCS-L от 8" до 9-1/2"
# 18        Фильтр для очистки воды Philips AWP230P3/58
# 19  Смазка GNV Amber Force LT EP00 GALT15710201924...
# 20      Кольцо дверцы превентора боковой F9301.10.00A
# 21              Емкость растворная мерник V-40 м3 б/у
# 22                    Фильтр масляный Sampiyon CS3000
# 23                            Трубка тормоза 30171956
# 24  Электродвигатель СЭТЗ ВАО80B4 У2 1,5кВт 1500об...
# 25                                  Салфетка бумажная
# 26                      Провод ПВС 2х1,5 ГОСТ 7399-97
# 27  Контактор компрессора кондиционера Marvair AVP...
# 28  Компоновка вращающаяся для горизонтальной цент...
# 29  Костюм Петролеум плюс, цвет темно-синий, разме...
# 30                 Кольцо 060-070-58-2-2 ГОСТ 9833-73
# 31  Бита торцевая магнитная Ritter WP сталь 10х65м...
# 32  Зажим промежуточный EKF PROxima SO270 2х25-35м...
# 33                Болт М12-6gх65.58(S18) ГОСТ 7805-70
# 34         Быстроразъемное соединение БРС-4 (БСПТ 4")
# 35       Клапан обратный с резьбой БРС МП70.00.09.000
# 36                              ПРОВОД ПЭТВ - 2 0,250
# 37  Плакат "Внимание! Вскрыт продуктивный пласт" 3...
# 38                  Полумуфта кулачковая 14007.78.017
# 39  Гидрораспределитель BE6.574A Г12 электроуправл...
# 40            Таз круглый 14л особо прочный цвет микс
# 41  Рация Baofeng UV-82 8Вт 3 режима мощности цвет...
# 42  Фильтр к респиратору РПГ-67 марка A1В1 упаковк...
# 43  Сапоги литьевые болотные с жестким подноском р.46
# 44             Кувалда К5Ф фиберглассовая ручка Вихрь
# 45                                        Кран 15 ВхВ
# 46  Винт с плоской головкой M8х20 для центрифуги М...
# 47       Датчик частоты вращения 3900мм 81.27120-6166
# 48            Гайка фланца моста переднего L913800400
# 49  Наклейка Осторожно электрическое напряжение 10...
# 50               Клапан уравновешивающий H09-1001-010
# 51  Выключатель автоматический EKF PROxima ВА 47-6...
# 52            Вешалка Пико 4 000952 Черный 820х65х430
# 53  Картридж лазерный Комус 055H Y цвет желтый 149...
# 54         Станция насосная OTGON Optima JP 4.2-55-50
# 55                              Фланец с БРС 2" 80х35
# 56  Выключатель автоматический ВА57-35-340010-200А...
# 57                                Кольцо УВ.01.003-08
# 58  Брюки мужские "Оператор" для защиты от понижен...
# 59  Машина шлифовальная угловая ШТУРМ УШМ 150/1400...
# 60                          Штуцер для шланга 1"х25мм
# 61                         Жилет сигнальный СОТ и СПК
# 62   Фильтр гидравлический 109512 (Filtrec DHD60G10B)
# 63                   Шайба плоская, тип А, 1/2", 1073
# 64  Трубка тормозная полиамидная d9мм (02507 1M FEB)I
# 65  Переводник П З-108Л/121Л-133/146-58/76-650 ст4...
# 66  Бак топливный Бакор КамАЗ 350л 530х650х1150 с ...
# 67                     Подшипник 3003144 ГОСТ 5721-75
# 68                  Бутылка ПЭ светлая 0,50 л матовая
# 69  Рейка для монтажа электротехнического оборудов...
# 70                Кольцо защитное Е64-286,4-300-2,0/3
# 71  Фитинг прямой для соединения пневмотрубок ( пл...
# 72  Манометр  ДМ8008-ВУф  Кс  исп  1  0-40  МПа кт...
# 73                Основание седла Камаз 65225-2702110
# 74                      Поли ТГП тампонажный материал
# 75        Крем восстанавливающий регенирирующий 100мл
# 76        Термобелье специальное р.52-54 рост 194-200
# 77               Перчатки Ansell Tiger Paw р.7 76-301
# 78                         Геохимические исследования
# 79  Услуга Установка компрессорная азот 60Мпа Ожид...
# 80  Охлаждение для ноутбука Dexp Gaming Series GS6...
# 81            Фильтр масляный ЭнергоРеусурс 98.03.014
# 82            Рукав Пар-2 (X) -8-18мм ТУ 38 605157-90
# 83  Камлок Dixon соединение тип C, муфта стыковочн...
# 84  Знак предупреждающий W19 Газовый баллон 250х25...
# 85                             Труба питающая 9440-00
# 86  Пена монтажная Makroflex ShakeTec Premium Mega...
# 87  Устройство защитного отключения УЗО ВД2-63-400 4Р
# 88  Услуга Установка компрессорная азот 5Мпа Ожида...
# 89             Крышка гидромотора поворота 39Q6-11281
# 90                     Кольцо цилиндра ER95531699 MAN
# 91                          РАДИАТОР 4002-22-1001 СБА
# 92          Электрод ОК 46.00P d 3мм 350 мм Esab-СВЭЛ
# 93                                     Нефть товарная
# 94                 Аммоний хлористый чда ГОСТ 3773-72
# 95     Гайка шпильки колеса малая для Урал 250565-П29
# 96  Мотор гидравлический для механизма поворота СВ...
# 97                Насос ручной подкачки Sampa 021.382
# 98                  Прокладка регулировочная 109586-2
# 99  Преобразователь давления измерительный СДВ-EX-...
#
#                                             очищенный  \
# 0   {'raw': 'Фитинг гидравлический стальной резьба...
# 1   {'raw': 'Кольцо уплотнительное 305-320-85 ГОСТ...
# 2   {'raw': 'Тумба бу(24374-13025)', 'html_cleaned...
# 3   {'raw': 'Замок вис. дисковый ВС2-26 СР', 'html...
# 4   {'raw': 'Тяга 14006.55.151-01', 'html_cleaned'...
# 5   {'raw': 'Уплотнение цилиндровой втулки 54025.5...
# 6   {'raw': 'Клапан челночный, HC01-07', 'html_cle...
# 7   {'raw': 'Маркер белый для промышленной графики...
# 8   {'raw': 'Шаблон полимерный под СБТ 114мм ТУ 36...
# 9   {'raw': 'Вагон-дом прачечная-душевая, на санях...
# 10  {'raw': 'Футболка хлопковая цвет васильковый (...
# 11  {'raw': 'Сальник для ввода кабеля в щитовое об...
# 12  {'raw': 'Кольцо 815-830-85-2-3  000.003.675.0 ...
# 13  {'raw': 'Тройник ПЭ 110*50', 'html_cleaned': '...
# 14  {'raw': 'Карандаш разметочный, 145 мм', 'html_...
# 15  {'raw': 'Картриджи для HP CF400x ,401x, 402x, ...
# 16  {'raw': 'Подвеска хвостовика гидромеханическая...
# 17  {'raw': 'Захват клиньевой DCS-L от 8" до 9-1/2...
# 18  {'raw': 'Фильтр для очистки воды Philips AWP23...
# 19  {'raw': 'Смазка GNV Amber Force LT EP00 GALT15...
# 20  {'raw': 'Кольцо дверцы превентора боковой F930...
# 21  {'raw': 'Емкость растворная мерник V-40 м3 б/у...
# 22  {'raw': 'Фильтр масляный Sampiyon CS3000', 'ht...
# 23  {'raw': 'Трубка тормоза 30171956', 'html_clean...
# 24  {'raw': 'Электродвигатель СЭТЗ ВАО80B4 У2 1,5к...
# 25  {'raw': 'Салфетка бумажная', 'html_cleaned': '...
# 26  {'raw': 'Провод ПВС 2х1,5 ГОСТ 7399-97', 'html...
# 27  {'raw': 'Контактор компрессора кондиционера Ma...
# 28  {'raw': 'Компоновка вращающаяся для горизонтал...
# 29  {'raw': 'Костюм Петролеум плюс, цвет темно-син...
# 30  {'raw': 'Кольцо 060-070-58-2-2 ГОСТ 9833-73', ...
# 31  {'raw': 'Бита торцевая магнитная Ritter WP ста...
# 32  {'raw': 'Зажим промежуточный EKF PROxima SO270...
# 33  {'raw': 'Болт М12-6gх65.58(S18) ГОСТ 7805-70',...
# 34  {'raw': 'Быстроразъемное соединение БРС-4 (БСП...
# 35  {'raw': 'Клапан обратный с резьбой БРС МП70.00...
# 36  {'raw': 'ПРОВОД ПЭТВ - 2 0,250', 'html_cleaned...
# 37  {'raw': 'Плакат "Внимание! Вскрыт продуктивный...
# 38  {'raw': 'Полумуфта кулачковая 14007.78.017', '...
# 39  {'raw': 'Гидрораспределитель BE6.574A Г12 элек...
# 40  {'raw': 'Таз круглый 14л особо прочный цвет ми...
# 41  {'raw': 'Рация Baofeng UV-82 8Вт 3 режима мощн...
# 42  {'raw': 'Фильтр к респиратору РПГ-67 марка A1В...
# 43  {'raw': 'Сапоги литьевые болотные с жестким по...
# 44  {'raw': 'Кувалда К5Ф фиберглассовая ручка Вихр...
# 45  {'raw': 'Кран 15 ВхВ', 'html_cleaned': 'Кран 1...
# 46  {'raw': 'Винт с плоской головкой M8х20 для цен...
# 47  {'raw': 'Датчик частоты вращения 3900мм 81.271...
# 48  {'raw': 'Гайка фланца моста переднего L9138004...
# 49  {'raw': 'Наклейка Осторожно электрическое напр...
# 50  {'raw': 'Клапан уравновешивающий H09-1001-010'...
# 51  {'raw': 'Выключатель автоматический EKF PROxim...
# 52  {'raw': 'Вешалка Пико 4 000952 Черный 820х65х4...
# 53  {'raw': 'Картридж лазерный Комус 055H Y цвет ж...
# 54  {'raw': 'Станция насосная OTGON Optima JP 4.2-...
# 55  {'raw': 'Фланец с БРС 2" 80х35', 'html_cleaned...
# 56  {'raw': 'Выключатель автоматический ВА57-35-34...
# 57  {'raw': 'Кольцо УВ.01.003-08', 'html_cleaned':...
# 58  {'raw': 'Брюки мужские "Оператор" для защиты о...
# 59  {'raw': 'Машина шлифовальная угловая ШТУРМ УШМ...
# 60  {'raw': 'Штуцер для шланга 1"х25мм', 'html_cle...
# 61  {'raw': 'Жилет сигнальный СОТ и СПК', 'html_cl...
# 62  {'raw': 'Фильтр гидравлический 109512 (Filtrec...
# 63  {'raw': 'Шайба плоская, тип А, 1/2", 1073', 'h...
# 64  {'raw': 'Трубка тормозная полиамидная d9мм (02...
# 65  {'raw': 'Переводник П З-108Л/121Л-133/146-58/7...
# 66  {'raw': 'Бак топливный Бакор КамАЗ 350л 530х65...
# 67  {'raw': 'Подшипник 3003144 ГОСТ 5721-75', 'htm...
# 68  {'raw': 'Бутылка ПЭ светлая 0,50 л матовая', '...
# 69  {'raw': 'Рейка для монтажа электротехнического...
# 70  {'raw': 'Кольцо защитное Е64-286,4-300-2,0/3',...
# 71  {'raw': 'Фитинг прямой для соединения пневмотр...
# 72  {'raw': 'Манометр  ДМ8008-ВУф  Кс  исп  1  0-4...
# 73  {'raw': 'Основание седла Камаз 65225-2702110',...
# 74  {'raw': 'Поли ТГП тампонажный материал', 'html...
# 75  {'raw': 'Крем восстанавливающий регенирирующий...
# 76  {'raw': 'Термобелье специальное р.52-54 рост 1...
# 77  {'raw': 'Перчатки Ansell Tiger Paw р.7 76-301'...
# 78  {'raw': 'Геохимические исследования', 'html_cl...
# 79  {'raw': 'Услуга Установка компрессорная азот 6...
# 80  {'raw': 'Охлаждение для ноутбука Dexp Gaming S...
# 81  {'raw': 'Фильтр масляный ЭнергоРеусурс 98.03.0...
# 82  {'raw': 'Рукав Пар-2 (X) -8-18мм ТУ 38 605157-...
# 83  {'raw': 'Камлок Dixon соединение тип C, муфта ...
# 84  {'raw': 'Знак предупреждающий W19 Газовый балл...
# 85  {'raw': 'Труба питающая 9440-00', 'html_cleane...
# 86  {'raw': 'Пена монтажная Makroflex ShakeTec Pre...
# 87  {'raw': 'Устройство защитного отключения УЗО В...
# 88  {'raw': 'Услуга Установка компрессорная азот 5...
# 89  {'raw': 'Крышка гидромотора поворота 39Q6-1128...
# 90  {'raw': 'Кольцо цилиндра ER95531699 MAN', 'htm...
# 91  {'raw': 'РАДИАТОР 4002-22-1001 СБА', 'html_cle...
# 92  {'raw': 'Электрод ОК 46.00P d 3мм 350 мм Esab-...
# 93  {'raw': 'Нефть товарная', 'html_cleaned': 'Неф...
# 94  {'raw': 'Аммоний хлористый чда ГОСТ 3773-72', ...
# 95  {'raw': 'Гайка шпильки колеса малая для Урал 2...
# 96  {'raw': 'Мотор гидравлический для механизма по...
# 97  {'raw': 'Насос ручной подкачки Sampa 021.382',...
# 98  {'raw': 'Прокладка регулировочная 109586-2', '...
# 99  {'raw': 'Преобразователь давления измерительны...
#
#                                       нормализованный  \
# 0   {'original': 'Фитинг гидравлический стальной р...
# 1   {'original': 'Кольцо уплотнительное 305-320-85...
# 2   {'original': 'Тумба бу(24374-13025)', 'units_n...
# 3   {'original': 'Замок вис. дисковый ВС2-26 СР', ...
# 4   {'original': 'Тяга 14006.55.151-01', 'units_no...
# 5   {'original': 'Уплотнение цилиндровой втулки 54...
# 6   {'original': 'Клапан челночный, HC01-07', 'uni...
# 7   {'original': 'Маркер белый для промышленной гр...
# 8   {'original': 'Шаблон полимерный под СБТ 114мм ...
# 9   {'original': 'Вагон-дом прачечная-душевая, на ...
# 10  {'original': 'Футболка хлопковая цвет василько...
# 11  {'original': 'Сальник для ввода кабеля в щитов...
# 12  {'original': 'Кольцо 815-830-85-2-3  000.003.6...
# 13  {'original': 'Тройник ПЭ 110*50', 'units_norma...
# 14  {'original': 'Карандаш разметочный, 145 мм', '...
# 15  {'original': 'Картриджи для HP CF400x ,401x, 4...
# 16  {'original': 'Подвеска хвостовика гидромеханич...
# 17  {'original': 'Захват клиньевой DCS-L от 8" до ...
# 18  {'original': 'Фильтр для очистки воды Philips ...
# 19  {'original': 'Смазка GNV Amber Force LT EP00 G...
# 20  {'original': 'Кольцо дверцы превентора боковой...
# 21  {'original': 'Емкость растворная мерник V-40 м...
# 22  {'original': 'Фильтр масляный Sampiyon CS3000'...
# 23  {'original': 'Трубка тормоза 30171956', 'units...
# 24  {'original': 'Электродвигатель СЭТЗ ВАО80B4 У2...
# 25  {'original': 'Салфетка бумажная', 'units_norma...
# 26  {'original': 'Провод ПВС 2х1,5 ГОСТ 7399-97', ...
# 27  {'original': 'Контактор компрессора кондиционе...
# 28  {'original': 'Компоновка вращающаяся для гориз...
# 29  {'original': 'Костюм Петролеум плюс, цвет темн...
# 30  {'original': 'Кольцо 060-070-58-2-2 ГОСТ 9833-...
# 31  {'original': 'Бита торцевая магнитная Ritter W...
# 32  {'original': 'Зажим промежуточный EKF PROxima ...
# 33  {'original': 'Болт М12-6gх65.58(S18) ГОСТ 7805...
# 34  {'original': 'Быстроразъемное соединение БРС-4...
# 35  {'original': 'Клапан обратный с резьбой БРС МП...
# 36  {'original': 'ПРОВОД ПЭТВ - 2 0,250', 'units_n...
# 37  {'original': 'Плакат "Внимание! Вскрыт продукт...
# 38  {'original': 'Полумуфта кулачковая 14007.78.01...
# 39  {'original': 'Гидрораспределитель BE6.574A Г12...
# 40  {'original': 'Таз круглый 14л особо прочный цв...
# 41  {'original': 'Рация Baofeng UV-82 8Вт 3 режима...
# 42  {'original': 'Фильтр к респиратору РПГ-67 марк...
# 43  {'original': 'Сапоги литьевые болотные с жестк...
# 44  {'original': 'Кувалда К5Ф фиберглассовая ручка...
# 45  {'original': 'Кран 15 ВхВ', 'units_normalized'...
# 46  {'original': 'Винт с плоской головкой M8х20 дл...
# 47  {'original': 'Датчик частоты вращения 3900мм 8...
# 48  {'original': 'Гайка фланца моста переднего L91...
# 49  {'original': 'Наклейка Осторожно электрическое...
# 50  {'original': 'Клапан уравновешивающий H09-1001...
# 51  {'original': 'Выключатель автоматический EKF P...
# 52  {'original': 'Вешалка Пико 4 000952 Черный 820...
# 53  {'original': 'Картридж лазерный Комус 055H Y ц...
# 54  {'original': 'Станция насосная OTGON Optima JP...
# 55  {'original': 'Фланец с БРС 2" 80х35', 'units_n...
# 56  {'original': 'Выключатель автоматический ВА57-...
# 57  {'original': 'Кольцо УВ.01.003-08', 'units_nor...
# 58  {'original': 'Брюки мужские "Оператор" для защ...
# 59  {'original': 'Машина шлифовальная угловая ШТУР...
# 60  {'original': 'Штуцер для шланга 1"х25мм', 'uni...
# 61  {'original': 'Жилет сигнальный СОТ и СПК', 'un...
# 62  {'original': 'Фильтр гидравлический 109512 (Fi...
# 63  {'original': 'Шайба плоская, тип А, 1/2", 1073...
# 64  {'original': 'Трубка тормозная полиамидная d9м...
# 65  {'original': 'Переводник П З-108Л/121Л-133/146...
# 66  {'original': 'Бак топливный Бакор КамАЗ 350л 5...
# 67  {'original': 'Подшипник 3003144 ГОСТ 5721-75',...
# 68  {'original': 'Бутылка ПЭ светлая 0,50 л матова...
# 69  {'original': 'Рейка для монтажа электротехниче...
# 70  {'original': 'Кольцо защитное Е64-286,4-300-2,...
# 71  {'original': 'Фитинг прямой для соединения пне...
# 72  {'original': 'Манометр  ДМ8008-ВУф  Кс  исп  1...
# 73  {'original': 'Основание седла Камаз 65225-2702...
# 74  {'original': 'Поли ТГП тампонажный материал', ...
# 75  {'original': 'Крем восстанавливающий регенирир...
# 76  {'original': 'Термобелье специальное р.52-54 р...
# 77  {'original': 'Перчатки Ansell Tiger Paw р.7 76...
# 78  {'original': 'Геохимические исследования', 'un...
# 79  {'original': 'Услуга Установка компрессорная а...
# 80  {'original': 'Охлаждение для ноутбука Dexp Gam...
# 81  {'original': 'Фильтр масляный ЭнергоРеусурс 98...
# 82  {'original': 'Рукав Пар-2 (X) -8-18мм ТУ 38 60...
# 83  {'original': 'Камлок Dixon соединение тип C, м...
# 84  {'original': 'Знак предупреждающий W19 Газовый...
# 85  {'original': 'Труба питающая 9440-00', 'units_...
# 86  {'original': 'Пена монтажная Makroflex ShakeTe...
# 87  {'original': 'Устройство защитного отключения ...
# 88  {'original': 'Услуга Установка компрессорная а...
# 89  {'original': 'Крышка гидромотора поворота 39Q6...
# 90  {'original': 'Кольцо цилиндра ER95531699 MAN',...
# 91  {'original': 'РАДИАТОР 4002-22-1001 СБА', 'uni...
# 92  {'original': 'Электрод ОК 46.00P d 3мм 350 мм ...
# 93  {'original': 'Нефть товарная', 'units_normaliz...
# 94  {'original': 'Аммоний хлористый чда ГОСТ 3773-...
# 95  {'original': 'Гайка шпильки колеса малая для У...
# 96  {'original': 'Мотор гидравлический для механиз...
# 97  {'original': 'Насос ручной подкачки Sampa 021....
# 98  {'original': 'Прокладка регулировочная 109586-...
# 99  {'original': 'Преобразователь давления измерит...
#
#                                     лемматизированный
# 0   {'original': 'Фитинг гидравлический стальной р...
# 1   {'original': 'Кольцо уплотнительное 305-320-85...
# 2   {'original': 'Тумба бу(24374-13025)', 'lemmati...
# 3   {'original': 'Замок вис. дисковый ВС2-26 СР', ...
# 4   {'original': 'Тяга 14006.55.151-01', 'lemmatiz...
# 5   {'original': 'Уплотнение цилиндровой втулки 54...
# 6   {'original': 'Клапан челночный, HC01-07', 'lem...
# 7   {'original': 'Маркер белый для промышленной гр...
# 8   {'original': 'Шаблон полимерный под СБТ 114мм ...
# 9   {'original': 'Вагон-дом прачечная-душевая, на ...
# 10  {'original': 'Футболка хлопковая цвет василько...
# 11  {'original': 'Сальник для ввода кабеля в щитов...
# 12  {'original': 'Кольцо 815-830-85-2-3  000.003.6...
# 13  {'original': 'Тройник ПЭ 110*50', 'lemmatized'...
# 14  {'original': 'Карандаш разметочный, 145 мм', '...
# 15  {'original': 'Картриджи для HP CF400x ,401x, 4...
# 16  {'original': 'Подвеска хвостовика гидромеханич...
# 17  {'original': 'Захват клиньевой DCS-L от 8" до ...
# 18  {'original': 'Фильтр для очистки воды Philips ...
# 19  {'original': 'Смазка GNV Amber Force LT EP00 G...
# 20  {'original': 'Кольцо дверцы превентора боковой...
# 21  {'original': 'Емкость растворная мерник V-40 м...
# 22  {'original': 'Фильтр масляный Sampiyon CS3000'...
# 23  {'original': 'Трубка тормоза 30171956', 'lemma...
# 24  {'original': 'Электродвигатель СЭТЗ ВАО80B4 У2...
# 25  {'original': 'Салфетка бумажная', 'lemmatized'...
# 26  {'original': 'Провод ПВС 2х1,5 ГОСТ 7399-97', ...
# 27  {'original': 'Контактор компрессора кондиционе...
# 28  {'original': 'Компоновка вращающаяся для гориз...
# 29  {'original': 'Костюм Петролеум плюс, цвет темн...
# 30  {'original': 'Кольцо 060-070-58-2-2 ГОСТ 9833-...
# 31  {'original': 'Бита торцевая магнитная Ritter W...
# 32  {'original': 'Зажим промежуточный EKF PROxima ...
# 33  {'original': 'Болт М12-6gх65.58(S18) ГОСТ 7805...
# 34  {'original': 'Быстроразъемное соединение БРС-4...
# 35  {'original': 'Клапан обратный с резьбой БРС МП...
# 36  {'original': 'ПРОВОД ПЭТВ - 2 0,250', 'lemmati...
# 37  {'original': 'Плакат "Внимание! Вскрыт продукт...
# 38  {'original': 'Полумуфта кулачковая 14007.78.01...
# 39  {'original': 'Гидрораспределитель BE6.574A Г12...
# 40  {'original': 'Таз круглый 14л особо прочный цв...
# 41  {'original': 'Рация Baofeng UV-82 8Вт 3 режима...
# 42  {'original': 'Фильтр к респиратору РПГ-67 марк...
# 43  {'original': 'Сапоги литьевые болотные с жестк...
# 44  {'original': 'Кувалда К5Ф фиберглассовая ручка...
# 45  {'original': 'Кран 15 ВхВ', 'lemmatized': 'кра...
# 46  {'original': 'Винт с плоской головкой M8х20 дл...
# 47  {'original': 'Датчик частоты вращения 3900мм 8...
# 48  {'original': 'Гайка фланца моста переднего L91...
# 49  {'original': 'Наклейка Осторожно электрическое...
# 50  {'original': 'Клапан уравновешивающий H09-1001...
# 51  {'original': 'Выключатель автоматический EKF P...
# 52  {'original': 'Вешалка Пико 4 000952 Черный 820...
# 53  {'original': 'Картридж лазерный Комус 055H Y ц...
# 54  {'original': 'Станция насосная OTGON Optima JP...
# 55  {'original': 'Фланец с БРС 2" 80х35', 'lemmati...
# 56  {'original': 'Выключатель автоматический ВА57-...
# 57  {'original': 'Кольцо УВ.01.003-08', 'lemmatize...
# 58  {'original': 'Брюки мужские "Оператор" для защ...
# 59  {'original': 'Машина шлифовальная угловая ШТУР...
# 60  {'original': 'Штуцер для шланга 1"х25мм', 'lem...
# 61  {'original': 'Жилет сигнальный СОТ и СПК', 'le...
# 62  {'original': 'Фильтр гидравлический 109512 (Fi...
# 63  {'original': 'Шайба плоская, тип А, 1/2", 1073...
# 64  {'original': 'Трубка тормозная полиамидная d9м...
# 65  {'original': 'Переводник П З-108Л/121Л-133/146...
# 66  {'original': 'Бак топливный Бакор КамАЗ 350л 5...
# 67  {'original': 'Подшипник 3003144 ГОСТ 5721-75',...
# 68  {'original': 'Бутылка ПЭ светлая 0,50 л матова...
# 69  {'original': 'Рейка для монтажа электротехниче...
# 70  {'original': 'Кольцо защитное Е64-286,4-300-2,...
# 71  {'original': 'Фитинг прямой для соединения пне...
# 72  {'original': 'Манометр  ДМ8008-ВУф  Кс  исп  1...
# 73  {'original': 'Основание седла Камаз 65225-2702...
# 74  {'original': 'Поли ТГП тампонажный материал', ...
# 75  {'original': 'Крем восстанавливающий регенирир...
# 76  {'original': 'Термобелье специальное р.52-54 р...
# 77  {'original': 'Перчатки Ansell Tiger Paw р.7 76...
# 78  {'original': 'Геохимические исследования', 'le...
# 79  {'original': 'Услуга Установка компрессорная а...
# 80  {'original': 'Охлаждение для ноутбука Dexp Gam...
# 81  {'original': 'Фильтр масляный ЭнергоРеусурс 98...
# 82  {'original': 'Рукав Пар-2 (X) -8-18мм ТУ 38 60...
# 83  {'original': 'Камлок Dixon соединение тип C, м...
# 84  {'original': 'Знак предупреждающий W19 Газовый...
# 85  {'original': 'Труба питающая 9440-00', 'lemmat...
# 86  {'original': 'Пена монтажная Makroflex ShakeTe...
# 87  {'original': 'Устройство защитного отключения ...
# 88  {'original': 'Услуга Установка компрессорная а...
# 89  {'original': 'Крышка гидромотора поворота 39Q6...
# 90  {'original': 'Кольцо цилиндра ER95531699 MAN',...
# 91  {'original': 'РАДИАТОР 4002-22-1001 СБА', 'lem...
# 92  {'original': 'Электрод ОК 46.00P d 3мм 350 мм ...
# 93  {'original': 'Нефть товарная', 'lemmatized': '...
# 94  {'original': 'Аммоний хлористый чда ГОСТ 3773-...
# 95  {'original': 'Гайка шпильки колеса малая для У...
# 96  {'original': 'Мотор гидравлический для механиз...
# 97  {'original': 'Насос ручной подкачки Sampa 021....
# 98  {'original': 'Прокладка регулировочная 109586-...
# 99  {'original': 'Преобразователь давления измерит...
# Memory usage high: 80.4% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 81.4% of limit
# High memory usage detected: 6.51GB
# Memory usage high: 81.1% of limit
# High memory usage detected: 6.49GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 83.7% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 85.0% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 81.9% of limit
# High memory usage detected: 6.55GB
# Memory usage high: 82.1% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 88.0% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 82.8% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 86.0% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 81.6% of limit
# High memory usage detected: 6.53GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 86.3% of limit
# High memory usage detected: 6.90GB
# Memory usage high: 88.9% of limit
# High memory usage detected: 7.11GB
# Memory usage critical: 90.4% of limit
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage high: 81.6% of limit
# High memory usage detected: 6.53GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 80.0% of limit
# High memory usage detected: 6.40GB
# Memory usage high: 81.2% of limit
# High memory usage detected: 6.50GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 84.6% of limit
# High memory usage detected: 6.77GB
# Memory usage critical: 93.5% of limit
# Memory usage high: 85.9% of limit
# High memory usage detected: 6.87GB
# Memory usage high: 85.0% of limit
# High memory usage detected: 6.80GB
# Memory usage critical: 90.5% of limit
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 87.1% of limit
# High memory usage detected: 6.97GB
# Memory usage high: 89.1% of limit
# High memory usage detected: 7.13GB
# Memory usage high: 88.4% of limit
# High memory usage detected: 7.07GB
# Memory usage high: 88.2% of limit
# High memory usage detected: 7.06GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 87.3% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 82.8% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 80.1% of limit
# High memory usage detected: 6.41GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 80.8% of limit
# High memory usage detected: 6.47GB
# Memory usage high: 80.7% of limit
# High memory usage detected: 6.46GB
# Memory usage high: 80.0% of limit
# High memory usage detected: 6.40GB
# Memory usage high: 81.0% of limit
# High memory usage detected: 6.48GB
# Memory usage high: 80.0% of limit
# High memory usage detected: 6.40GB
# Memory usage high: 80.1% of limit
# High memory usage detected: 6.41GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 86.0% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage critical: 90.3% of limit
# Memory usage high: 89.3% of limit
# High memory usage detected: 7.14GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 80.7% of limit
# High memory usage detected: 6.46GB
# Memory usage high: 88.1% of limit
# High memory usage detected: 7.05GB
# Memory usage critical: 90.5% of limit
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 81.3% of limit
# High memory usage detected: 6.50GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 89.1% of limit
# High memory usage detected: 7.13GB
# Memory usage critical: 96.0% of limit
# Memory usage critical: 98.8% of limit
# Memory usage critical: 97.5% of limit
# Memory usage critical: 103.7% of limit
# Memory usage critical: 101.2% of limit
# Memory usage critical: 101.5% of limit
# Memory usage critical: 101.1% of limit
# Memory usage critical: 97.6% of limit
# Memory usage critical: 99.6% of limit
# Memory usage high: 81.3% of limit
# High memory usage detected: 6.50GB
# Memory usage critical: 91.3% of limit
# Memory usage critical: 97.3% of limit
# Memory usage critical: 98.4% of limit
# Memory usage critical: 97.5% of limit
# Memory usage critical: 101.1% of limit
# Memory usage critical: 101.1% of limit
# Memory usage critical: 101.6% of limit
# Memory usage critical: 101.2% of limit
# Memory usage critical: 101.2% of limit
# Memory usage critical: 101.7% of limit
# Memory usage critical: 100.8% of limit
# Memory usage critical: 100.5% of limit
# Memory usage critical: 98.5% of limit
# Memory usage critical: 98.8% of limit
# Memory usage critical: 99.6% of limit
# Memory usage critical: 97.3% of limit
# Memory usage critical: 97.2% of limit
# Memory usage critical: 95.6% of limit
# Memory usage critical: 96.3% of limit
# Memory usage critical: 96.1% of limit
# Memory usage critical: 95.0% of limit
# Memory usage critical: 94.7% of limit
# Memory usage critical: 93.8% of limit
# Memory usage critical: 93.7% of limit
# Memory usage critical: 94.0% of limit
# Memory usage critical: 92.0% of limit
# Memory usage critical: 95.2% of limit
# Memory usage critical: 93.8% of limit
# Memory usage critical: 94.1% of limit
# Memory usage critical: 94.3% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 93.2% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 93.5% of limit
# Memory usage critical: 93.9% of limit
# Memory usage critical: 93.8% of limit
# Memory usage critical: 94.9% of limit
# Memory usage critical: 93.2% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 93.4% of limit
# Memory usage critical: 93.3% of limit
# Memory usage critical: 93.5% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 93.5% of limit
# Memory usage critical: 93.4% of limit
# Memory usage critical: 93.2% of limit
# Memory usage critical: 93.3% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 93.5% of limit
# Memory usage critical: 92.5% of limit
# Memory usage critical: 92.5% of limit
# Memory usage critical: 93.5% of limit
# Memory usage critical: 91.2% of limit
# Memory usage critical: 92.2% of limit
# Memory usage critical: 92.2% of limit
# Memory usage critical: 91.3% of limit
# Memory usage critical: 90.6% of limit
# Memory usage critical: 92.4% of limit
# Memory usage critical: 92.6% of limit
# Memory usage critical: 92.7% of limit
# Memory usage critical: 91.3% of limit
# Memory usage critical: 92.0% of limit
# Memory usage critical: 91.4% of limit
# Memory usage critical: 93.9% of limit
# Memory usage critical: 92.8% of limit
# Memory usage critical: 92.8% of limit
# Memory usage critical: 91.7% of limit
# Memory usage critical: 94.3% of limit
# Memory usage critical: 93.7% of limit
# Memory usage critical: 93.2% of limit
# Memory usage critical: 93.8% of limit
# Memory usage critical: 93.4% of limit
# Memory usage critical: 92.3% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 92.7% of limit
# Memory usage critical: 92.5% of limit
# Memory usage critical: 92.2% of limit
# Memory usage critical: 92.6% of limit
# Memory usage critical: 92.9% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 93.1% of limit
# Memory usage critical: 92.5% of limit
# Memory usage critical: 92.0% of limit
# Memory usage critical: 93.3% of limit
# Memory usage critical: 92.4% of limit
# Memory usage critical: 92.8% of limit
# Memory usage critical: 91.3% of limit
# Memory usage critical: 92.8% of limit
# Memory usage critical: 92.6% of limit
# Memory usage critical: 92.3% of limit
# Memory usage critical: 92.6% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 92.5% of limit
# Memory usage critical: 91.4% of limit
# Memory usage critical: 91.2% of limit
# Memory usage critical: 91.0% of limit
# Memory usage critical: 91.5% of limit
# Memory usage critical: 90.8% of limit
# Memory usage critical: 91.7% of limit
# Memory usage critical: 91.0% of limit
# Memory usage critical: 91.5% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 91.6% of limit
# Memory usage critical: 91.6% of limit
# Memory usage critical: 92.2% of limit
# Memory usage critical: 92.4% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 91.5% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 91.2% of limit
# Memory usage critical: 91.7% of limit
# Memory usage critical: 91.9% of limit
# Memory usage critical: 91.1% of limit
# Memory usage critical: 91.6% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 90.3% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 90.3% of limit
# Memory usage critical: 92.4% of limit
# Memory usage critical: 91.3% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 92.1% of limit
# Memory usage critical: 90.7% of limit
# Memory usage critical: 91.8% of limit
# Memory usage critical: 92.3% of limit
# Memory usage critical: 91.1% of limit
# Memory usage critical: 91.3% of limit
# Memory usage high: 90.0% of limit
# High memory usage detected: 7.20GB
# Memory usage critical: 90.2% of limit
# Memory usage high: 89.6% of limit
# High memory usage detected: 7.17GB
# Memory usage high: 88.9% of limit
# High memory usage detected: 7.11GB
# Memory usage high: 88.8% of limit
# High memory usage detected: 7.11GB
# Memory usage high: 88.9% of limit
# High memory usage detected: 7.11GB
# Memory usage high: 89.6% of limit
# High memory usage detected: 7.17GB
# Memory usage critical: 91.9% of limit
# Memory usage critical: 91.6% of limit
# Memory usage critical: 92.6% of limit
# Memory usage high: 89.4% of limit
# High memory usage detected: 7.15GB
# Memory usage critical: 90.8% of limit
# Memory usage high: 88.9% of limit
# High memory usage detected: 7.11GB
# Memory usage high: 89.1% of limit
# High memory usage detected: 7.13GB
# Memory usage high: 89.8% of limit
# High memory usage detected: 7.18GB
# Memory usage high: 87.3% of limit
# High memory usage detected: 6.98GB
# Memory usage high: 89.7% of limit
# High memory usage detected: 7.17GB
# Memory usage critical: 90.8% of limit
# Memory usage critical: 91.4% of limit
# Memory usage critical: 91.3% of limit
# Memory usage critical: 90.1% of limit
# Memory usage critical: 90.9% of limit
# Memory usage high: 88.8% of limit
# High memory usage detected: 7.10GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 89.1% of limit
# High memory usage detected: 7.13GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 88.1% of limit
# High memory usage detected: 7.05GB
# Memory usage high: 88.8% of limit
# High memory usage detected: 7.10GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 87.9% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 86.1% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 85.0% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 87.8% of limit
# High memory usage detected: 7.03GB
# Memory usage high: 88.0% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 87.6% of limit
# High memory usage detected: 7.01GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.85GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 86.8% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 88.0% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 88.1% of limit
# High memory usage detected: 7.05GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 87.2% of limit
# High memory usage detected: 6.98GB
# Memory usage high: 87.9% of limit
# High memory usage detected: 7.03GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 87.8% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 88.0% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 86.8% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 87.1% of limit
# High memory usage detected: 6.97GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.90GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.90GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.85GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.87GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 88.5% of limit
# High memory usage detected: 7.08GB
# Memory usage high: 88.2% of limit
# High memory usage detected: 7.06GB
# Memory usage high: 87.9% of limit
# High memory usage detected: 7.03GB
# Memory usage high: 87.1% of limit
# High memory usage detected: 6.97GB
# Memory usage high: 86.1% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 86.8% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 86.8% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 88.2% of limit
# High memory usage detected: 7.05GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 88.6% of limit
# High memory usage detected: 7.08GB
# Memory usage high: 85.6% of limit
# High memory usage detected: 6.85GB
# Memory usage high: 85.9% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 88.3% of limit
# High memory usage detected: 7.06GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 88.0% of limit
# High memory usage detected: 7.04GB
# Memory usage high: 87.8% of limit
# High memory usage detected: 7.02GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 87.1% of limit
# High memory usage detected: 6.97GB
# Memory usage high: 86.1% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 87.5% of limit
# High memory usage detected: 7.00GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 87.3% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 87.3% of limit
# High memory usage detected: 6.98GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 87.5% of limit
# High memory usage detected: 7.00GB
# Memory usage high: 85.9% of limit
# High memory usage detected: 6.87GB
# Memory usage high: 87.5% of limit
# High memory usage detected: 7.00GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 87.2% of limit
# High memory usage detected: 6.97GB
# Memory usage high: 86.7% of limit
# High memory usage detected: 6.94GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.01GB
# Memory usage high: 87.7% of limit
# High memory usage detected: 7.01GB
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 87.4% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 86.3% of limit
# High memory usage detected: 6.90GB
# Memory usage high: 86.0% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 86.1% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.85GB
# Memory usage high: 85.9% of limit
# High memory usage detected: 6.87GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.6% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 81.2% of limit
# High memory usage detected: 6.49GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 82.2% of limit
# High memory usage detected: 6.58GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.60GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 83.2% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 86.6% of limit
# High memory usage detected: 6.93GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 85.8% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 86.2% of limit
# High memory usage detected: 6.90GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 85.6% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 87.3% of limit
# High memory usage detected: 6.99GB
# Memory usage high: 86.0% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 85.9% of limit
# High memory usage detected: 6.88GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 86.1% of limit
# High memory usage detected: 6.89GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 85.7% of limit
# High memory usage detected: 6.86GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 84.6% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 83.2% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 85.6% of limit
# High memory usage detected: 6.85GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 83.7% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 81.7% of limit
# High memory usage detected: 6.54GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.4% of limit
# ...
# High memory usage detected: 6.78GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 82.8% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 80.2% of limit
# High memory usage detected: 6.42GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 81.8% of limit
# High memory usage detected: 6.54GB
# Memory usage high: 81.8% of limit
# High memory usage detected: 6.54GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 80.8% of limit
# High memory usage detected: 6.47GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.58GB
# Memory usage high: 82.1% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 82.1% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 81.8% of limit
# High memory usage detected: 6.55GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 85.0% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 82.8% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 81.9% of limit
# High memory usage detected: 6.55GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 81.6% of limit
# High memory usage detected: 6.53GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 83.2% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 83.2% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 82.5% of limit
# High memory usage detected: 6.60GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 81.1% of limit
# High memory usage detected: 6.49GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.69GB
# Memory usage high: 83.7% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 86.9% of limit
# High memory usage detected: 6.95GB
# Memory usage high: 86.4% of limit
# High memory usage detected: 6.91GB
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 85.3% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 83.7% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.60GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 80.4% of limit
# High memory usage detected: 6.43GB
# Memory usage high: 81.7% of limit
# High memory usage detected: 6.54GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 81.4% of limit
# High memory usage detected: 6.51GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.4% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 82.1% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 80.1% of limit
# High memory usage detected: 6.41GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 83.6% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 84.6% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 83.5% of limit
# High memory usage detected: 6.68GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.77GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 81.2% of limit
# High memory usage detected: 6.49GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 84.7% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 83.7% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 85.0% of limit
# High memory usage detected: 6.80GB
# Memory usage high: 85.1% of limit
# High memory usage detected: 6.81GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 85.5% of limit
# High memory usage detected: 6.84GB
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.9% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.78GB
# Memory usage high: 83.8% of limit
# High memory usage detected: 6.70GB
# Memory usage high: 84.2% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 81.2% of limit
# High memory usage detected: 6.49GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.66GB
# Memory usage high: 83.2% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 80.3% of limit
# High memory usage detected: 6.43GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 82.0% of limit
# High memory usage detected: 6.56GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 82.6% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 82.4% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 81.6% of limit
# High memory usage detected: 6.53GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 82.0% of limit
# High memory usage detected: 6.56GB
# Memory usage high: 82.0% of limit
# High memory usage detected: 6.56GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 80.4% of limit
# High memory usage detected: 6.43GB
# Memory usage high: 80.9% of limit
# High memory usage detected: 6.47GB
# Memory usage high: 81.8% of limit
# High memory usage detected: 6.55GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 82.2% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 80.6% of limit
# High memory usage detected: 6.45GB
# Memory usage high: 81.2% of limit
# High memory usage detected: 6.50GB
# Memory usage high: 80.7% of limit
# High memory usage detected: 6.45GB
# Memory usage high: 83.3% of limit
# High memory usage detected: 6.67GB
# Memory usage high: 81.6% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB
# Memory usage high: 81.9% of limit
# High memory usage detected: 6.55GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 84.0% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 85.4% of limit
# High memory usage detected: 6.83GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.73GB
# Memory usage high: 84.6% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.58GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.58GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 82.5% of limit
# High memory usage detected: 6.60GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 84.5% of limit
# High memory usage detected: 6.76GB
# Memory usage high: 82.7% of limit
# High memory usage detected: 6.61GB
# Memory usage high: 84.8% of limit
# High memory usage detected: 6.79GB
# Memory usage high: 84.3% of limit
# High memory usage detected: 6.74GB
# Memory usage high: 85.2% of limit
# High memory usage detected: 6.82GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 80.9% of limit
# High memory usage detected: 6.48GB
# Memory usage high: 80.8% of limit
# High memory usage detected: 6.47GB
# Memory usage high: 81.4% of limit
# High memory usage detected: 6.51GB
# Memory usage high: 83.9% of limit
# High memory usage detected: 6.71GB
# Memory usage high: 84.1% of limit
# High memory usage detected: 6.72GB
# Memory usage high: 84.4% of limit
# High memory usage detected: 6.75GB
# Memory usage high: 83.1% of limit
# High memory usage detected: 6.65GB
# Memory usage high: 80.2% of limit
# High memory usage detected: 6.42GB
# Memory usage high: 81.4% of limit
# High memory usage detected: 6.51GB
# Memory usage high: 80.7% of limit
# High memory usage detected: 6.46GB
# Memory usage high: 80.0% of limit
# High memory usage detected: 6.40GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 82.3% of limit
# High memory usage detected: 6.59GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 82.0% of limit
# High memory usage detected: 6.56GB
# Memory usage high: 82.2% of limit
# High memory usage detected: 6.57GB
# Memory usage high: 82.2% of limit
# High memory usage detected: 6.58GB
# Memory usage high: 80.3% of limit
# High memory usage detected: 6.42GB
# Memory usage high: 82.8% of limit
# High memory usage detected: 6.62GB
# Memory usage high: 80.2% of limit
# High memory usage detected: 6.41GB
# Memory usage high: 80.5% of limit
# High memory usage detected: 6.44GB
# Memory usage high: 80.0% of limit
# High memory usage detected: 6.40GB
# Memory usage high: 80.7% of limit
# High memory usage detected: 6.46GB
# Memory usage high: 80.4% of limit
# High memory usage detected: 6.43GB
# Memory usage critical: 102.1% of limit
# Memory usage critical: 102.2% of limit
# Memory usage critical: 100.7% of limit
# Memory usage high: 87.0% of limit
# High memory usage detected: 6.96GB
# Memory usage critical: 101.8% of limit
# Memory usage critical: 92.3% of limit
# Memory usage critical: 90.0% of limit
# Memory usage high: 86.5% of limit
# High memory usage detected: 6.92GB
# Memory usage high: 81.7% of limit
# High memory usage detected: 6.53GB
# Memory usage high: 83.0% of limit
# High memory usage detected: 6.64GB
# Memory usage high: 82.9% of limit
# High memory usage detected: 6.63GB
# Memory usage high: 81.3% of limit
# High memory usage detected: 6.50GB
# Memory usage high: 81.3% of limit
# High memory usage detected: 6.50GB
# Memory usage high: 81.0% of limit
# High memory usage detected: 6.48GB
# Memory usage high: 81.5% of limit
# High memory usage detected: 6.52GB

# %% [markdown]
# ## 3️⃣ Анализ метрик сходства и сопоставления

# %% [markdown]
# ### 3.1 Сравнение алгоритмов строкового сходства

# %%
if MAIN_NAME_COL:
    # Выбор выборки для тестирования сходства
    sample_size = min(500, len(product_names))
    similarity_sample = product_names.sample(sample_size, random_state=42).tolist()
    
    print(f"=== СРАВНЕНИЕ АЛГОРИТМОВ СХОДСТВА ===")
    print(f"Тестирование на {len(similarity_sample)} названиях товаров")
    
    # Определение функций сходства
    similarity_functions = {
        'Левенштейн (RapidFuzz)': lambda x, y: fuzz.ratio(x, y) / 100,
        'Частичное соотношение': lambda x, y: fuzz.partial_ratio(x, y) / 100,
        'Соотношение сортировки токенов': lambda x, y: fuzz.token_sort_ratio(x, y) / 100,
        'Соотношение множества токенов': lambda x, y: fuzz.token_set_ratio(x, y) / 100,
        'FuzzyWuzzy соотношение': lambda x, y: fuzz_wuzzy.ratio(x, y) / 100
    }
    
    # Тестирование алгоритмов сходства на парах образцов
    import time
    
    # Генерация тестовых пар
    test_pairs = []
    for i in range(min(100, len(similarity_sample))):
        # Похожие пары (один товар с вариациями)
        base_name = similarity_sample[i]
        # Создание вариации путем добавления/удаления слов
        words = base_name.split()
        if len(words) > 1:
            variation = ' '.join(words[:-1])  # Удаление последнего слова
            test_pairs.append((base_name, variation, 'похожие'))
        
        # Непохожие пары
        if i < len(similarity_sample) - 1:
            test_pairs.append((similarity_sample[i], similarity_sample[i+1], 'разные'))
    
    # Бенчмарк функций сходства
    results = {}
    
    for func_name, func in similarity_functions.items():
        print(f"\nТестирование {func_name}...")
        
        start_time = time.time()
        similarities = []
        
        for pair1, pair2, pair_type in test_pairs[:50]:  # Тест на первых 50 парах
            try:
                sim_score = func(pair1, pair2)
                similarities.append((sim_score, pair_type))
            except Exception as e:
                print(f"  Ошибка с {func_name}: {e}")
                continue
        
        end_time = time.time()
        
        if similarities:
            # Расчет метрик производительности
            similar_scores = [s[0] for s in similarities if s[1] == 'похожие']
            different_scores = [s[0] for s in similarities if s[1] == 'разные']
            
            results[func_name] = {
                'среднее_время_сравнения': (end_time - start_time) / len(similarities),
                'средний_балл_похожих': np.mean(similar_scores) if similar_scores else 0,
                'средний_балл_разных': np.mean(different_scores) if different_scores else 0,
                'разделение_баллов': (np.mean(similar_scores) - np.mean(different_scores)) if similar_scores and different_scores else 0
            }
    
    # Отображение результатов
    if results:
        results_df = pd.DataFrame(results).T
        results_df = results_df.round(4)
        print("\n=== ПРОИЗВОДИТЕЛЬНОСТЬ АЛГОРИТМОВ СХОДСТВА ===")
        display(results_df)
# Out:
# === СРАВНЕНИЕ АЛГОРИТМОВ СХОДСТВА ===
# Тестирование на 500 названиях товаров
#
# Тестирование Левенштейн (RapidFuzz)...
#
# Тестирование Частичное соотношение...
#
# Тестирование Соотношение сортировки токенов...
#
# Тестирование Соотношение множества токенов...
#
# Тестирование FuzzyWuzzy соотношение...
#
# === ПРОИЗВОДИТЕЛЬНОСТЬ АЛГОРИТМОВ СХОДСТВА ===
#                                 среднее_время_сравнения  средний_балл_похожих  \
# Левенштейн (RapidFuzz)                              0.0                0.8564
# Частичное соотношение                               0.0                0.9978
# Соотношение сортировки токенов                      0.0                0.8572
# Соотношение множества токенов                       0.0                1.0000
# FuzzyWuzzy соотношение                              0.0                0.8568
#
#                                 средний_балл_разных  разделение_баллов
# Левенштейн (RapidFuzz)                       0.2708             0.5856
# Частичное соотношение                        0.3198             0.6780
# Соотношение сортировки токенов               0.2751             0.5820
# Соотношение множества токенов                0.2751             0.7249
# FuzzyWuzzy соотношение                       0.2700             0.5868

# %% [markdown]
# ### 3.2 Анализ семантического сходства

# %%
# Семантическое сходство с использованием TF-IDF и косинусного сходства
if MAIN_NAME_COL:
    print("=== АНАЛИЗ СЕМАНТИЧЕСКОГО СХОДСТВА ===")
    
    # Подготовка текста для TF-IDF
    semantic_sample = product_names.sample(min(1000, len(product_names)), random_state=42)
    
    # Создание TF-IDF векторов
    print("Создание TF-IDF векторов...")
    
    # TF-IDF на уровне символов
    char_vectorizer = TfidfVectorizer(
        analyzer='char',
        ngram_range=(2, 4),
        max_features=5000,
        lowercase=True
    )
    
    # TF-IDF на уровне слов
    word_vectorizer = TfidfVectorizer(
        analyzer='word',
        ngram_range=(1, 2),
        max_features=5000,
        lowercase=True,
        stop_words=list(stop_words)
    )
    
    try:
        char_tfidf = char_vectorizer.fit_transform(semantic_sample)
        word_tfidf = word_vectorizer.fit_transform(semantic_sample)
        
        print(f"Размер символьного TF-IDF: {char_tfidf.shape}")
        print(f"Размер словесного TF-IDF: {word_tfidf.shape}")
        
        # Расчет матриц сходства для небольшого подмножества
        subset_size = min(100, char_tfidf.shape[0])
        char_subset = char_tfidf[:subset_size]
        word_subset = word_tfidf[:subset_size]
        
        char_similarity = cosine_similarity(char_subset)
        word_similarity = cosine_similarity(word_subset)
        
        print(f"\n=== СТАТИСТИКА МАТРИЦЫ СХОДСТВА ===")
        print(f"Сходство на уровне символов:")
        print(f"  Среднее: {np.mean(char_similarity):.4f}")
        print(f"  Ст. откл.: {np.std(char_similarity):.4f}")
        print(f"  Максимум: {np.max(char_similarity):.4f}")
        
        print(f"\nСходство на уровне слов:")
        print(f"  Среднее: {np.mean(word_similarity):.4f}")
        print(f"  Ст. откл.: {np.std(word_similarity):.4f}")
        print(f"  Максимум: {np.max(word_similarity):.4f}")
        
        # Поиск наиболее похожих пар
        print(f"\n=== НАИБОЛЕЕ ПОХОЖИЕ ПАРЫ ТОВАРОВ ===")
        
        # Получение индексов наиболее похожих пар (исключая диагональ)
        np.fill_diagonal(char_similarity, 0)  # Удаление само-сходства
        top_indices = np.unravel_index(np.argsort(char_similarity.ravel())[-10:], char_similarity.shape)
        
        sample_list = semantic_sample.iloc[:subset_size].tolist()
        
        for i, (idx1, idx2) in enumerate(zip(top_indices[0][-5:], top_indices[1][-5:])):
            similarity_score = char_similarity[idx1, idx2]
            print(f"{i+1}. Сходство: {similarity_score:.4f}")
            print(f"   Товар 1: {sample_list[idx1]}")
            print(f"   Товар 2: {sample_list[idx2]}")
            print()
        
    except Exception as e:
        print(f"⚠️ Ошибка в анализе семантического сходства: {e}")
# Out:
# === АНАЛИЗ СЕМАНТИЧЕСКОГО СХОДСТВА ===
# Создание TF-IDF векторов...
# Размер символьного TF-IDF: (1000, 5000)
# Размер словесного TF-IDF: (1000, 5000)
#
# === СТАТИСТИКА МАТРИЦЫ СХОДСТВА ===
# Сходство на уровне символов:
#   Среднее: 0.0456
#   Ст. откл.: 0.1052
#   Максимум: 1.0000
#
# Сходство на уровне слов:
#   Среднее: 0.0132
#   Ст. откл.: 0.1014
#   Максимум: 1.0000
#
# === НАИБОЛЕЕ ПОХОЖИЕ ПАРЫ ТОВАРОВ ===
# 1. Сходство: 0.6224
#    Товар 1: Подшипник 3518Н ГОСТ 5721-75
#    Товар 2: Подшипник 50-92152М ГОСТ 520-89
#
# 2. Сходство: 0.6855
#    Товар 1: Жилет утепленный цвет оранжевый р.56-58 рост 158-164
#    Товар 2: Жилет утепленный цвет оранжевый р.68-70 рост 206-212
#
# 3. Сходство: 0.6855
#    Товар 1: Жилет утепленный цвет оранжевый р.68-70 рост 206-212
#    Товар 2: Жилет утепленный цвет оранжевый р.56-58 рост 158-164
#
# 4. Сходство: 0.8779
#    Товар 1: Подшипник 3518Н ГОСТ 5721-75
#    Товар 2: Подшипник 3609 ГОСТ 5721-75
#
# 5. Сходство: 0.8779
#    Товар 1: Подшипник 3609 ГОСТ 5721-75
#    Товар 2: Подшипник 3518Н ГОСТ 5721-75

# %% [markdown]
# ## 4️⃣ Анализ категоризации и кластеризации

# %% [markdown]
# ### 4.1 Анализ распределения категорий товаров

# %%
# Анализ категорий товаров, если доступны
category_analysis = {}

if CATEGORY_COL:
    print(f"=== АНАЛИЗ КАТЕГОРИЙ ({CATEGORY_COL}) ===")
    
    category_counts = df[CATEGORY_COL].value_counts()
    category_analysis['основные_категории'] = category_counts
    
    print(f"Всего категорий: {len(category_counts)}")
    print(f"Наиболее популярные категории:")
    for cat, count in category_counts.head(10).items():
        percentage = (count / len(df)) * 100
        print(f"  • {cat}: {count:,} товаров ({percentage:.1f}%)")
    
    # Покрытие категорий
    missing_categories = df[CATEGORY_COL].isnull().sum()
    coverage = ((len(df) - missing_categories) / len(df)) * 100
    print(f"\nПокрытие категорий: {coverage:.1f}% ({len(df) - missing_categories:,} товаров)")

if SUBCATEGORY_COL:
    print(f"\n=== АНАЛИЗ ПОДКАТЕГОРИЙ ({SUBCATEGORY_COL}) ===")
    
    subcategory_counts = df[SUBCATEGORY_COL].value_counts()
    category_analysis['подкатегории'] = subcategory_counts
    
    print(f"Всего подкатегорий: {len(subcategory_counts)}")
    print(f"Наиболее популярные подкатегории:")
    for subcat, count in subcategory_counts.head(10).items():
        percentage = (count / len(df)) * 100
        print(f"  • {subcat}: {count:,} товаров ({percentage:.1f}%)")
    
    # Покрытие подкатегорий
    missing_subcategories = df[SUBCATEGORY_COL].isnull().sum()
    subcoverage = ((len(df) - missing_subcategories) / len(df)) * 100
    print(f"\nПокрытие подкатегорий: {subcoverage:.1f}% ({len(df) - missing_subcategories:,} товаров)")

# Анализ иерархии категорий
if CATEGORY_COL and SUBCATEGORY_COL:
    print(f"\n=== АНАЛИЗ ИЕРАРХИИ КАТЕГОРИЙ ===")
    
    hierarchy = df.groupby([CATEGORY_COL, SUBCATEGORY_COL]).size().reset_index(name='количество')
    hierarchy = hierarchy.sort_values('количество', ascending=False)
    
    print(f"Всего комбинаций категория-подкатегория: {len(hierarchy)}")
    print(f"\nТоп-10 пар категория-подкатегория:")
    for _, row in hierarchy.head(10).iterrows():
        print(f"  • {row[CATEGORY_COL]} → {row[SUBCATEGORY_COL]}: {row['количество']:,} товаров")
    
    category_analysis['иерархия'] = hierarchy
# Out:
# === АНАЛИЗ КАТЕГОРИЙ (Группа) ===
# Всего категорий: 991
# Наиболее популярные категории:
#   • АВАНСОВЫЙ ОТЧЕТ: 14,704 товаров (11.3%)
#   • Запасные части к грузовым автомобилям: 7,716 товаров (5.9%)
#   • Запасные части к тракторам, специальной и дорожной технике: 5,175 товаров (4.0%)
#   • Инструмент слесарно-монтажный: 3,717 товаров (2.9%)
#   • Одежда специальная летняя: 2,886 товаров (2.2%)
#   • Одежда специальная зимняя: 2,242 товаров (1.7%)
#   • ЗИП к оборудованию Canrig: 1,621 товаров (1.2%)
#   • ЗИП к оборудованию Tesco: 1,487 товаров (1.1%)
#   • Переводники для бурильных колонн: 1,408 товаров (1.1%)
#   • ЗИП к оборудованию National Oilwell Varco (NOV): 1,343 товаров (1.0%)
#
# Покрытие категорий: 100.0% (130,303 товаров)
#
# === АНАЛИЗ ПОДКАТЕГОРИЙ (ВидНоменклатуры) ===
# Всего подкатегорий: 39
# Наиболее популярные подкатегории:
#   • Запасные части: 49,468 товаров (38.0%)
#   • Сырье и материалы: 23,577 товаров (18.1%)
#   • Инвентарь и хозяйственные принадлежности: 20,321 товаров (15.6%)
#   • Спецодежда: 10,836 товаров (8.3%)
#   • Спецоснастка: 2,640 товаров (2.0%)
#   • Строительные материалы: 2,544 товаров (2.0%)
#   • Основное средство: 2,196 товаров (1.7%)
#   • Аварийный инструмент и инвентарь: 2,152 товаров (1.7%)
#   • Запасные части к БО: 2,116 товаров (1.6%)
#   • Услуга: 2,089 товаров (1.6%)
#
# Покрытие подкатегорий: 100.0% (130,303 товаров)
#
# === АНАЛИЗ ИЕРАРХИИ КАТЕГОРИЙ ===
# Всего комбинаций категория-подкатегория: 2693
#
# Топ-10 пар категория-подкатегория:
#   • Запасные части к грузовым автомобилям → Запасные части: 7,599 товаров
#   • АВАНСОВЫЙ ОТЧЕТ → Сырье и материалы: 4,997 товаров
#   • Запасные части к тракторам, специальной и дорожной технике → Запасные части: 4,306 товаров
#   • АВАНСОВЫЙ ОТЧЕТ → Инвентарь и хозяйственные принадлежности: 4,060 товаров
#   • Инструмент слесарно-монтажный → Инвентарь и хозяйственные принадлежности: 3,139 товаров
#   • Одежда специальная летняя → Спецодежда: 2,877 товаров
#   • АВАНСОВЫЙ ОТЧЕТ → Запасные части: 2,649 товаров
#   • Одежда специальная зимняя → Спецодежда: 2,238 товаров
#   • ЗИП к оборудованию Canrig → Запасные части: 1,608 товаров
#   • ЗИП к оборудованию Tesco → Запасные части: 1,471 товаров

# %% [markdown]
# ### 4.2 Визуализация распределения категорий

# %%
# Визуализация распределения категорий
if category_analysis:
    fig = make_subplots(
        rows=4, cols=1,
        subplot_titles=('Топ категории', 'Топ подкатегории', 
                       'Распределение размеров категорий', 'Тепловая карта иерархии'),
        specs=[[{"type": "bar"}], [{"type": "bar"}], 
               [{"type": "histogram"}], [{"type": "heatmap"}]]
    )
    
    # Топ категории
    if 'основные_категории' in category_analysis:
        top_cats = category_analysis['основные_категории'].head(15)
        fig.add_trace(
            go.Bar(x=top_cats.values, y=top_cats.index, orientation='h',
                   name='Категории', marker_color='blue'),
            row=1, col=1
        )
    
    # Топ подкатегории
    if 'подкатегории' in category_analysis:
        top_subcats = category_analysis['подкатегории'].head(15)
        fig.add_trace(
            go.Bar(x=top_subcats.values, y=top_subcats.index, orientation='h',
                   name='Подкатегории', marker_color='green'),
            row=2, col=1
        )
    
    # Распределение размеров категорий
    if 'основные_категории' in category_analysis:
        fig.add_trace(
            go.Histogram(x=category_analysis['основные_категории'].values,
                        nbinsx=30, name='Размеры категорий', marker_color='orange'),
            row=3, col=1
        )

    # Тепловая карта иерархии (если доступна)
    if 'иерархия' in category_analysis and len(category_analysis['иерархия']) > 0:
        # Создание сводной таблицы для тепловой карты
        hierarchy_pivot = category_analysis['иерархия'].pivot_table(
            index=CATEGORY_COL, columns=SUBCATEGORY_COL, values='количество', fill_value=0
        )
        
        # Ограничение топ категориями и подкатегориями для читаемости
        top_categories = category_analysis['основные_категории'].head(10).index
        top_subcategories = category_analysis['подкатегории'].head(15).index
        
        hierarchy_subset = hierarchy_pivot.loc[
            hierarchy_pivot.index.intersection(top_categories),
            hierarchy_pivot.columns.intersection(top_subcategories)
        ]
        
        fig.add_trace(
            go.Heatmap(z=hierarchy_subset.values,
                      x=hierarchy_subset.columns,
                      y=hierarchy_subset.index,
                      colorscale='Blues',
                      name='Иерархия'),
            row=4, col=1
        )
    
    fig.update_layout(height=800, showlegend=False,
                     title_text="Панель анализа категорий")
    fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b21c8813-1cb2-45ea-86e4-5ad854db0c14" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b21c8813-1cb2-45ea-86e4-5ad854db0c14")) {                    Plotly.newPlot(                        "b21c8813-1cb2-45ea-86e4-5ad854db0c14",                        [{"marker":{"color":"blue"},"name":"\u041a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u0438","orientation":"h","x":{"dtype":"i2","bdata":"cDkkHjcUhQ5GC8IIVQbPBYAFPwUZBekEmQSPBIwE"},"y":["\u0410\u0412\u0410\u041d\u0421\u041e\u0412\u042b\u0419 \u041e\u0422\u0427\u0415\u0422","\u0417\u0430\u043f\u0430\u0441\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438 \u043a \u0433\u0440\u0443\u0437\u043e\u0432\u044b\u043c \u0430\u0432\u0442\u043e\u043c\u043e\u0431\u0438\u043b\u044f\u043c","\u0417\u0430\u043f\u0430\u0441\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438 \u043a \u0442\u0440\u0430\u043a\u0442\u043e\u0440\u0430\u043c, \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u043e\u0439 \u0438 \u0434\u043e\u0440\u043e\u0436\u043d\u043e\u0439 \u0442\u0435\u0445\u043d\u0438\u043a\u0435","\u0418\u043d\u0441\u0442\u0440\u0443\u043c\u0435\u043d\u0442 \u0441\u043b\u0435\u0441\u0430\u0440\u043d\u043e-\u043c\u043e\u043d\u0442\u0430\u0436\u043d\u044b\u0439","\u041e\u0434\u0435\u0436\u0434\u0430 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u0430\u044f \u043b\u0435\u0442\u043d\u044f\u044f","\u041e\u0434\u0435\u0436\u0434\u0430 \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u0430\u044f \u0437\u0438\u043c\u043d\u044f\u044f","\u0417\u0418\u041f \u043a \u043e\u0431\u043e\u0440\u0443\u0434\u043e\u0432\u0430\u043d\u0438\u044e Canrig","\u0417\u0418\u041f \u043a \u043e\u0431\u043e\u0440\u0443\u0434\u043e\u0432\u0430\u043d\u0438\u044e Tesco","\u041f\u0435\u0440\u0435\u0432\u043e\u0434\u043d\u0438\u043a\u0438 \u0434\u043b\u044f \u0431\u0443\u0440\u0438\u043b\u044c\u043d\u044b\u0445 \u043a\u043e\u043b\u043e\u043d\u043d","\u0417\u0418\u041f \u043a \u043e\u0431\u043e\u0440\u0443\u0434\u043e\u0432\u0430\u043d\u0438\u044e National Oilwell Varco (NOV)","\u0417\u0418\u041f \u043a \u043a\u043b\u044e\u0447\u0430\u043c \u0410\u0422\u0422","\u0417\u0418\u041f \u043a \u043a\u043b\u044e\u0447\u0430\u043c \u0413\u041a\u0428","\u041e\u0431\u0443\u0432\u044c \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u0430\u044f \u0437\u0438\u043c\u043d\u044f\u044f","\u041a\u043e\u043b\u044c\u0446\u0430 \u0443\u043f\u043b\u043e\u0442\u043d\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0435, \u043c\u0430\u043d\u0436\u0435\u0442\u044b","\u041e\u0431\u0443\u0432\u044c \u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u0430\u044f \u043b\u0435\u0442\u043d\u044f\u044f"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"green"},"name":"\u041f\u043e\u0434\u043a\u0430\u0442\u0435\u0433\u043e\u0440\u0438\u0438","orientation":"h","x":{"dtype":"i4","bdata":"PMEAABlcAABhTwAAVCoAAFAKAADwCQAAlAgAAGgIAABECAAAKQgAADAGAADEBAAArAQAAHsEAABsBAAA"},"y":["\u0417\u0430\u043f\u0430\u0441\u043d\u044b\u0435 \u0447\u0430\u0441\u0442\u0438","\u0421\u044b\u0440\u044c\u0435 \u0438 \u043c\u0430\u0442\u0435\u0440\u0438\u0430\u043b\u044b","\u0418\u043d\u0432\u0435\u043d\u0442\u0430\u0440\u044c \u0438 \u0445\u043e\u0437\u044f\u0439\u0441\u0442\u0432\u0435\u043d\u043d\u044b\u0435 \u043f\u0440\u0438\u043d\u0430\u0434\u043b\u0435\u0436\u043d\u043e\u0441\u0442\u0438","\u0421\u043f\u0435\u0446\u043e\u0434\u0435\u0436\u0434\u0430","\u0421\u043f\u0435\u0446\u043e\u0441\u043d\u0430\u0441\u0442\u043a\u0430","\u0421\u0442\u0440\u043e\u0438\u0442\u0435\u043b\u044c\u043d\u044b\u0435 \u043c\u0430\u0442\u0435\u0440\u0438\u0430\u043b\u044b","\u041e\u0441\u043d\u043e\u0432\u043d\u043 ...

# %% [markdown]
# ## 5️⃣ Оптимизация производительности поиска

# %% [markdown]
# ### 5.1 Рекомендации по структуре индексов

# %%
# Анализ оптимальных структур индексов для производительности поиска
print("=== АНАЛИЗ ОПТИМИЗАЦИИ ИНДЕКСОВ ПОИСКА ===")

if MAIN_NAME_COL:
    # Расчет статистики индексов
    total_products = len(df)
    unique_products = df[MAIN_NAME_COL].nunique()
    avg_name_length = df[MAIN_NAME_COL].str.len().mean()
    
    print(f"\n=== ОЦЕНКИ РАЗМЕРА ИНДЕКСОВ ===")
    print(f"Всего товаров: {total_products:,}")
    print(f"Уникальных товаров: {unique_products:,}")
    print(f"Средняя длина названия: {avg_name_length:.1f} символов")
    
    # Оценки памяти для разных типов индексов
    char_index_size = total_products * avg_name_length * 2  # UTF-8 кодировка
    tfidf_index_size = total_products * 5000 * 4  # Предполагая 5000 признаков, 4 байта на float
    
    print(f"\n=== ОЦЕНКИ ПАМЯТИ ===")
    print(f"Индекс сырого текста: {char_index_size / 1024**2:.1f} МБ")
    print(f"Индекс TF-IDF: {tfidf_index_size / 1024**2:.1f} МБ")
    
    # Рекомендации по производительности
    print(f"\n=== РЕКОМЕНДАЦИИ ПО ПРОИЗВОДИТЕЛЬНОСТИ ===")
    
    if total_products < 10000:
        print("📊 Малый датасет (<10К товаров):")
        print("  • Используйте TF-IDF в памяти с косинусным сходством")
        print("  • Простое нечеткое сопоставление для точного поиска")
        print("  • Нет необходимости в сложной индексации")
    elif total_products < 100000:
        print("📊 Средний датасет (10К-100К товаров):")
        print("  • Используйте FAISS для векторного поиска по сходству")
        print("  • Реализуйте n-граммную индексацию для нечеткого сопоставления")
        print("  • Рассмотрите предварительную фильтрацию по категориям")
    else:
        print("📊 Большой датасет (>100К товаров):")
        print("  • Используйте распределенный поиск (Elasticsearch/Solr)")
        print("  • Реализуйте иерархическую кластеризацию для предварительной фильтрации")
        print("  • Используйте приближенный поиск ближайших соседей")
    
    # Рекомендации по оптимизации запросов
    print(f"\n=== ОПТИМИЗАЦИЯ ЗАПРОСОВ ===")
    print("🔍 Рекомендуемый пайплайн поиска:")
    print("  1. Предобработка текста (очистка, нормализация)")
    print("  2. Фильтрация по категориям (если категория известна)")
    print("  3. Нечеткое сопоставление для точного поиска товаров")
    print("  4. Семантическое сходство для поиска аналогов")
    print("  5. Ранжирование результатов и дедупликация")
    
    # Рекомендации по кэшированию
    print(f"\n=== СТРАТЕГИЯ КЭШИРОВАНИЯ ===")
    print("💾 Рекомендуемое кэширование:")
    print("  • Кэширование TF-IDF векторов для частых товаров")
    print("  • Кэширование матриц сходства для кластеров товаров")
    print("  • Реализация кэширования результатов запросов с TTL")
    print("  • Использование Redis для распределенного кэширования")
# Out:
# === АНАЛИЗ ОПТИМИЗАЦИИ ИНДЕКСОВ ПОИСКА ===
#
# === ОЦЕНКИ РАЗМЕРА ИНДЕКСОВ ===
# Всего товаров: 130,303
# Уникальных товаров: 128,937
# Средняя длина названия: 49.0 символов
#
# === ОЦЕНКИ ПАМЯТИ ===
# Индекс сырого текста: 12.2 МБ
# Индекс TF-IDF: 2485.3 МБ
#
# === РЕКОМЕНДАЦИИ ПО ПРОИЗВОДИТЕЛЬНОСТИ ===
# 📊 Большой датасет (>100К товаров):
#   • Используйте распределенный поиск (Elasticsearch/Solr)
#   • Реализуйте иерархическую кластеризацию для предварительной фильтрации
#   • Используйте приближенный поиск ближайших соседей
#
# === ОПТИМИЗАЦИЯ ЗАПРОСОВ ===
# 🔍 Рекомендуемый пайплайн поиска:
#   1. Предобработка текста (очистка, нормализация)
#   2. Фильтрация по категориям (если категория известна)
#   3. Нечеткое сопоставление для точного поиска товаров
#   4. Семантическое сходство для поиска аналогов
#   5. Ранжирование результатов и дедупликация
#
# === СТРАТЕГИЯ КЭШИРОВАНИЯ ===
# 💾 Рекомендуемое кэширование:
#   • Кэширование TF-IDF векторов для частых товаров
#   • Кэширование матриц сходства для кластеров товаров
#   • Реализация кэширования результатов запросов с TTL
#   • Использование Redis для распределенного кэширования

# %% [markdown]
# ## 6️⃣ Резюме и рекомендации

# %% [markdown]
# ### 6.1 Резюме ключевых выводов

# %%
# Генерация комплексного резюме анализа
print("=== РЕЗЮМЕ АНАЛИЗА СИСТЕМЫ ПОИСКА АНАЛОГОВ SAMe ===")
print("=" * 60)

# Обзор датасета
if MAIN_NAME_COL and MAIN_NAME_COL in df.columns:
    # Очистка данных для точного подсчета
    clean_names_summary = df[MAIN_NAME_COL].dropna().astype(str)
    clean_names_summary = clean_names_summary[clean_names_summary.str.strip() != '']
    
    total_clean = len(clean_names_summary)
    unique_clean = clean_names_summary.nunique()
    duplicate_rate = ((total_clean - unique_clean) / total_clean * 100) if total_clean > 0 else 0
    avg_length = clean_names_summary.str.len().mean() if total_clean > 0 else 0
    
    print(f"\n📊 ОБЗОР ДАТАСЕТА:")
    print(f"  • Всего товаров: {len(df):,}")
    print(f"  • Товаров с названиями: {total_clean:,}")
    print(f"  • Уникальных названий товаров: {unique_clean:,}")
    print(f"  • Средняя длина названия: {avg_length:.1f} символов")
    print(f"  • Процент дубликатов: {duplicate_rate:.1f}%")

# Анализ категорий
if CATEGORY_COL:
    print(f"\n🏷️ КАТЕГОРИЗАЦИЯ:")
    print(f"  • Основных категорий: {df[CATEGORY_COL].nunique()}")
    print(f"  • Покрытие категорий: {((len(df) - df[CATEGORY_COL].isnull().sum()) / len(df) * 100):.1f}%")
    if SUBCATEGORY_COL:
        print(f"  • Подкатегорий: {df[SUBCATEGORY_COL].nunique()}")
        print(f"  • Покрытие подкатегорий: {((len(df) - df[SUBCATEGORY_COL].isnull().sum()) / len(df) * 100):.1f}%")

# Выводы текстового анализа
if MAIN_NAME_COL and MAIN_NAME_COL in df.columns:
    # Используем уже очищенные данные
    if 'clean_names_summary' in locals() and len(clean_names_summary) > 0:
        text_data = clean_names_summary
    else:
        text_data = df[MAIN_NAME_COL].dropna().astype(str)
        text_data = text_data[text_data.str.strip() != '']
    
    if len(text_data) > 0:
        cyrillic_pct = (text_data.str.contains(r'[а-яё]', case=False, regex=True).sum() / len(text_data)) * 100
        numeric_pct = (text_data.str.contains(r'\d', regex=True).sum() / len(text_data)) * 100
        avg_words = text_data.str.split().str.len().mean()
        
        print(f"\n📝 ХАРАКТЕРИСТИКИ ТЕКСТА:")
        print(f"  • Кириллический текст: {cyrillic_pct:.1f}% товаров")
        print(f"  • Содержит цифры: {numeric_pct:.1f}% товаров")
        print(f"  • Среднее количество слов в названии: {avg_words:.1f}")
    else:
        print(f"\n📝 ХАРАКТЕРИСТИКИ ТЕКСТА: Нет данных для анализа")

# Рекомендации по производительности
print(f"\n⚡ РЕКОМЕНДАЦИИ ПО ПРОИЗВОДИТЕЛЬНОСТИ:")
if len(df) < 10000:
    print(f"  • Размер датасета: Малый (<10К) - Используйте обработку в памяти")
    print(f"  • Рекомендуется: TF-IDF + Косинусное сходство")
elif len(df) < 100000:
    print(f"  • Размер датасета: Средний (10К-100К) - Используйте FAISS индексацию")
    print(f"  • Рекомендуется: Гибридный нечеткий + семантический поиск")
else:
    print(f"  • Размер датасета: Большой (>100К) - Используйте распределенный поиск")
    print(f"  • Рекомендуется: Elasticsearch с пользовательскими анализаторами")

print(f"\n🎯 ПОРОГИ СХОДСТВА:")
print(f"  • Высокая точность (точные совпадения): ≥ 0.90")
print(f"  • Сбалансированный (похожие товары): ≥ 0.80")
print(f"  • Высокая полнота (широкое сопоставление): ≥ 0.70")

print(f"\n🔧 ПРИОРИТЕТЫ РЕАЛИЗАЦИИ:")
print(f"  1. Реализовать надежный пайплайн предобработки текста")
print(f"  2. Создать фильтры поиска с учетом категорий")
print(f"  3. Построить гибридный движок нечеткого + семантического сходства")
print(f"  4. Реализовать ранжирование результатов и дедупликацию")
print(f"  5. Добавить мониторинг производительности и оптимизацию")

print(f"\n✅ АНАЛИЗ ЗАВЕРШЕН УСПЕШНО!")
print(f"📋 Данный анализ обеспечивает основу для построения эффективной системы поиска аналогов.")
# Out:
# === РЕЗЮМЕ АНАЛИЗА СИСТЕМЫ ПОИСКА АНАЛОГОВ SAMe ===
# ============================================================
#
# 📊 ОБЗОР ДАТАСЕТА:
#   • Всего товаров: 130,303
#   • Товаров с названиями: 130,303
#   • Уникальных названий товаров: 128,937
#   • Средняя длина названия: 49.0 символов
#   • Процент дубликатов: 1.0%
#
# 🏷️ КАТЕГОРИЗАЦИЯ:
#   • Основных категорий: 991
#   • Покрытие категорий: 100.0%
#   • Подкатегорий: 39
#   • Покрытие подкатегорий: 100.0%
#
# 📝 ХАРАКТЕРИСТИКИ ТЕКСТА:
#   • Кириллический текст: 100.0% товаров
#   • Содержит цифры: 94.7% товаров
#   • Среднее количество слов в названии: 6.3
#
# ⚡ РЕКОМЕНДАЦИИ ПО ПРОИЗВОДИТЕЛЬНОСТИ:
#   • Размер датасета: Большой (>100К) - Используйте распределенный поиск
#   • Рекомендуется: Elasticsearch с пользовательскими анализаторами
#
# 🎯 ПОРОГИ СХОДСТВА:
#   • Высокая точность (точные совпадения): ≥ 0.90
#   • Сбалансированный (похожие товары): ≥ 0.80
#   • Высокая полнота (широкое сопоставление): ≥ 0.70
#
# 🔧 ПРИОРИТЕТЫ РЕАЛИЗАЦИИ:
#   1. Реализовать надежный пайплайн предобработки текста
#   2. Создать фильтры поиска с учетом категорий
#   3. Построить гибридный движок нечеткого + семантического сходства
#   4. Реализовать ранжирование результатов и дедупликацию
#   5. Добавить мониторинг производительности и оптимизацию
#
# ✅ АНАЛИЗ ЗАВЕРШЕН УСПЕШНО!
# 📋 Данный анализ обеспечивает основу для построения эффективной системы поиска аналогов.
